# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import numpy as np
import scipy.sparse as sp
import tensorflow as tf
from tensorflow import keras
from keras import backend as K
from keras import initializers
from keras.models import Sequential, Model, load_model, save_model
from keras.layers.core import Dense, Lambda, Activation
from keras.layers import Embedding, Input, Dense, Multiply, Reshape, Flatten, Concatenate
from keras.optimizers import Adam
from keras.regularizers import l2
import pandas as pd

import json, sys, random, os, datetime, math
print(tf.__version__)
# Out:
# 2.3.0

# %%
from_json_df = pd.read_json('/content/gdrive/My Drive/NCF_video_bundle/video_bundle_data2.json')

# %%
from_json_df.head(5)

# %%
# traindata = pd.read_csv("/content/gdrive/My Drive/NCF_video_bundle/video_bundle_data.csv") 
traindata = from_json_df[['bundle_name','bundle_id','items']]

# %%
traindata.head()

# %%
complete_array = []
for index, row in traindata.iterrows():
  for item in row['items']:
    complete_array.append([item['item_id'], item['item_name'], item['genre'], row['bundle_id']])
df = pd.DataFrame(complete_array, columns=['item_id', 'item_name', 'genre', 'bundle_id'])
print(df.shape)
df.head()
# Out:
# (3525, 4)
#   item_id  ... bundle_id
# 0  326950  ...  450
# 1  331490  ...  450
# 2  331491  ...  450
# 3  331492  ...  450
# 4  348540  ...  450
#
# [5 rows x 4 columns]

# %%
item_ids = df["item_id"].unique().tolist()
len(item_ids)
item2item_encoded = {x: i for i, x in enumerate(item_ids)}
item_encoded2item = {i: x for i, x in enumerate(item_ids)}
df['itemId'] = df["item_id"].map(item2item_encoded)

df.head()
# Out:
#   item_id                           item_name  ... bundle_id  itemId
# 0  326950  Sword of Asumi                      ...  450       0
# 1  331490  Sword of Asumi - Soundtrack         ...  450       1
# 2  331491  Sword of Asumi - Graphic Novel      ...  450       2
# 3  331492  Sword of Asumi - Character Creator  ...  450       3
# 4  348540  Divine Slice of Life                ...  450       4
#
# [5 rows x 5 columns]

# %%
bundle_ids = df["bundle_id"].unique().tolist()
bundle2bundle_encoded = {x: i for i, x in enumerate(bundle_ids)}
bundle_encoded2bundle = {i: x for i, x in enumerate(bundle_ids)}
df["bundleId"] = df["bundle_id"].map(bundle2bundle_encoded)
df.head()
# Out:
#   item_id                           item_name  ... itemId  bundleId
# 0  326950  Sword of Asumi                      ...  0      0
# 1  331490  Sword of Asumi - Soundtrack         ...  1      0
# 2  331491  Sword of Asumi - Graphic Novel      ...  2      0
# 3  331492  Sword of Asumi - Character Creator  ...  3      0
# 4  348540  Divine Slice of Life                ...  4      0
#
# [5 rows x 6 columns]

# %%
# split training and challenge data
msk = np.random.rand(len(df)) < 0.8
train = df[msk]
challenge = df[~msk]
train.head()
# Out:
#   item_id                           item_name  ... itemId  bundleId
# 0  326950  Sword of Asumi                      ...  0      0
# 1  331490  Sword of Asumi - Soundtrack         ...  1      0
# 3  331492  Sword of Asumi - Character Creator  ...  3      0
# 4  348540  Divine Slice of Life                ...  4      0
# 5  352010  Beach Bounce                        ...  5      0
#
# [5 rows x 6 columns]

# %%
challenge.head()
# Out:
#    item_id  ... bundleId
# 2   331491  ...  0
# 9   408770  ...  0
# 13  396620  ...  0
# 28  528381  ...  2
# 38  528391  ...  2
#
# [5 rows x 6 columns]

# %%
# %%time
# save data in dok matrix (optimized sparse matrix object)
# create a sparse playlistid x trackindex matrix
# if a playlistid i has song j, mat[i,j]=1
mat = sp.dok_matrix((train.shape[0], len(df['itemId'].unique())), dtype=np.float32)
for bundle_id, item_id in zip(train['bundleId'], train['itemId']):
    # print(f'{bundle_id}, {item_id}')
    # print(mat.shape)
    mat[bundle_id, item_id] = 1.0
# sp.save_npz('steam_train_matrix.npz', mat)

# %%
def get_model(num_users, num_items, latent_dim=8, dense_layers=[64, 32, 16, 8],
              reg_layers=[0, 0, 0, 0], reg_mf=0):

    # input layer
    input_user = Input(shape=(1,), dtype='int32', name='user_input')
    input_item = Input(shape=(1,), dtype='int32', name='item_input')

    print(reg_mf)
    
    # embedding layer
    mf_user_embedding = Embedding(input_dim=num_users, output_dim=latent_dim,
                        name='mf_user_embedding',
                        embeddings_initializer='RandomNormal',
                        embeddings_regularizer=l2(reg_mf), input_length=1)
    mf_item_embedding = Embedding(input_dim=num_items, output_dim=latent_dim,
                        name='mf_item_embedding',
                        embeddings_initializer='RandomNormal',
                        embeddings_regularizer=l2(reg_mf), input_length=1)
    mlp_user_embedding = Embedding(input_dim=num_users, output_dim=int(dense_layers[0]/2),
                         name='mlp_user_embedding',
                         embeddings_initializer='RandomNormal',
                         embeddings_regularizer=l2(reg_layers[0]), 
                         input_length=1)
    mlp_item_embedding = Embedding(input_dim=num_items, output_dim=int(dense_layers[0]/2),
                         name='mlp_item_embedding',
                         embeddings_initializer='RandomNormal',
                         embeddings_regularizer=l2(reg_layers[0]), 
                         input_length=1)

    # MF latent vector
    mf_user_latent = Flatten()(mf_user_embedding(input_user))
    mf_item_latent = Flatten()(mf_item_embedding(input_item))
    mf_cat_latent = Multiply()([mf_user_latent, mf_item_latent])

    # MLP latent vector
    mlp_user_latent = Flatten()(mlp_user_embedding(input_user))
    mlp_item_latent = Flatten()(mlp_item_embedding(input_item))
    mlp_cat_latent = Concatenate()([mlp_user_latent, mlp_item_latent])
    
    mlp_vector = mlp_cat_latent
    
    # build dense layer for model
    for i in range(1,len(dense_layers)):
        layer = Dense(dense_layers[i],
                      activity_regularizer=l2(reg_layers[i]),
                      activation='relu',
                      name='layer%d' % i)
        mlp_vector = layer(mlp_vector)

    predict_layer = Concatenate()([mf_cat_latent, mlp_vector])
    result = Dense(1, activation='sigmoid', 
                   kernel_initializer='lecun_uniform',name='result')

    model = Model(inputs=[input_user,input_item], outputs=result(predict_layer))

    return model

# get the training samples
def get_train_samples(train_mat, num_negatives):
    user_input, item_input, labels = [], [], []
    num_user, num_item = train_mat.shape
    for (u, i) in train_mat.keys():
        user_input.append(u)
        item_input.append(i)
        labels.append(1)
        # negative instances
        for t in range(num_negatives):
            j = np.random.randint(num_item)
            while (u, j) in train_mat.keys():
                j = np.random.randint(num_item)
            user_input.append(u)
            item_input.append(j)
            labels.append(0)
    return user_input, item_input, labels

# hyperparameters
loaded = True
verbose = 1
epochs = 15   
batch_size = 256
latent_dim = 8
dense_layers = [64, 32, 16, 8]
reg_layers = [0, 0, 0, 0]
reg_mf = [0]
num_negatives = 4
learning_rate = 0.001
learner = 'adam'
dataset = 'steam_video'

# loading data
if loaded:
    train_mat = mat
else:
    train_mat = sp.load_npz('steam_train_matrix.npz')
    
num_users, num_items = train_mat.shape
print('Done loading data!')
# Out:
# Done loading data!

# %%
# get model
model = get_model(num_users, num_items, latent_dim, dense_layers, reg_layers)
model.compile(optimizer=Adam(lr=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
print(model.summary())
    
# train model
# generate training instances
user_input, item_input, labels = get_train_samples(train_mat, num_negatives)

# training
hist = model.fit([np.array(user_input), np.array(item_input)], np.array(labels), 
                 batch_size=batch_size, epochs=epochs, verbose=verbose, shuffle=True)
# Out:
# 0
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# user_input (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# item_input (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# mlp_user_embedding (Embedding)  (None, 1, 32)        89440       user_input[0][0]
# __________________________________________________________________________________________________
# mlp_item_embedding (Embedding)  (None, 1, 32)        89536       item_input[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 32)           0           mlp_user_embedding[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 32)           0           mlp_item_embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64)           0           flatten_6[0][0]
#                                                                  flatten_7[0][0]
# __________________________________________________________________________________________________
# mf_user_embedding (Embedding)   (None, 1, 8)         22360       user_input[0][0]
# __________________________________________________________________________________________________
# mf_item_embedding (Embedding)   (None, 1, 8)         22384       item_input[0][0]
# __________________________________________________________________________________________________
# layer1 (Dense)                  (None, 32)           2080        concatenate_2[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 8)            0           mf_user_embedding[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 8)            0           mf_item_embedding[0][0]
# __________________________________________________________________________________________________
# layer2 (Dense)                  (None, 16)           528         layer1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 8)            0           flatten_4[0][0]
#                                                                  flatten_5[0][0]
# __________________________________________________________________________________________________
# layer3 (Dense)                  (None, 8)            136         layer2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16)           0           multiply_1[0][0]
#                                                                  layer3[0][0]
# __________________________________________________________________________________________________
# result (Dense)                  (None, 1)            17          concatenate_3[0][0]
# ==================================================================================================
# Total params: 226,481
# Trainable params: 226,481
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/50
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:432: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 55/55 [==============================] - 0s 3ms/step - loss: 0.6112 - accuracy: 0.7989
# Epoch 2/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.5058 - accuracy: 0.8000
# Epoch 3/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.4885 - accuracy: 0.8000
# Epoch 4/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.4725 - accuracy: 0.8000
# Epoch 5/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.4554 - accuracy: 0.8000
# Epoch 6/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.4373 - accuracy: 0.8000
# Epoch 7/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.4074 - accuracy: 0.8032
# Epoch 8/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.3447 - accuracy: 0.8355
# Epoch 9/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.2455 - accuracy: 0.9039
# Epoch 10/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1438 - accuracy: 0.9589
# Epoch 11/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0699 - accuracy: 0.9877
# Epoch 12/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 0.9963
# Epoch 13/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 0.9985
# Epoch 14/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 0.9996
# Epoch 15/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 0.9999
# Epoch 16/50
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 0.9999
# Epoch 17/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 0.9999
# Epoch 18/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 19/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 20/50
# 55/55 [==============================] - 0s 3ms/step - loss: 9.3663e-04 - accuracy: 1.0000
# Epoch 21/50
# 55/55 [==============================] - 0s 3ms/step - loss: 7.7630e-04 - accuracy: 1.0000
# Epoch 22/50
# 55/55 [==============================] - 0s 3ms/step - loss: 6.5633e-04 - accuracy: 1.0000
# Epoch 23/50
# 55/55 [==============================] - 0s 2ms/step - loss: 5.6194e-04 - accuracy: 1.0000
# Epoch 24/50
# 55/55 [==============================] - 0s 3ms/step - loss: 4.8751e-04 - accuracy: 1.0000
# Epoch 25/50
# 55/55 [==============================] - 0s 3ms/step - loss: 4.2509e-04 - accuracy: 1.0000
# Epoch 26/50
# 55/55 [==============================] - 0s 3ms/step - loss: 3.7582e-04 - accuracy: 1.0000
# Epoch 27/50
# 55/55 [==============================] - 0s 3ms/step - loss: 3.3336e-04 - accuracy: 1.0000
# Epoch 28/50
# 55/55 [==============================] - 0s 3ms/step - loss: 2.9807e-04 - accuracy: 1.0000
# Epoch 29/50
# 55/55 [==============================] - 0s 3ms/step - loss: 2.6754e-04 - accuracy: 1.0000
# Epoch 30/50
# 55/55 [==============================] - 0s 3ms/step - loss: 2.4195e-04 - accuracy: 1.0000
# Epoch 31/50
# 55/55 [==============================] - 0s 3ms/step - loss: 2.1919e-04 - accuracy: 1.0000
# Epoch 32/50
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9985e-04 - accuracy: 1.0000
# Epoch 33/50
# 55/55 [==============================] - 0s 3ms/step - loss: 1.8230e-04 - accuracy: 1.0000
# Epoch 34/50
# 55/55 [==============================] - 0s 3ms/step - loss: 1.6705e-04 - accuracy: 1.0000
# Epoch 35/50
# 55/55 [==============================] - 0s 2ms/step - loss: 1.5370e-04 - accuracy: 1.0000
# Epoch 36/50
# 55/55 [==============================] - 0s 3ms/step - loss: 1.4157e-04 - accuracy: 1.0000
# Epoch 37/50
# 55/55 [==============================] - 0s 3ms/step - loss: 1.3084e-04 - accuracy: 1.0000
# Epoch 38/50
# 55/55 [==============================] - 0s 3ms/step - loss: 1.2116e-04 - accuracy: 1.0000
# Epoch 39/50
# 55/55 [==============================] - 0s 3ms/step - loss: 1.1247e-04 - accuracy: 1.0000
# Epoch 40/50
# 55/55 [==============================] - 0s 3ms/step - loss: 1.0456e-04 - accuracy: 1.0000
# Epoch 41/50
# 55/55 [==============================] - 0s 3ms/step - loss: 9.7443e-05 - accuracy: 1.0000
# Epoch 42/50
# 55/55 [==============================] - 0s 2ms/step - loss: 9.1001e-05 - accuracy: 1.0000
# Epoch 43/50
# 55/55 [==============================] - 0s 3ms/step - loss: 8.5011e-05 - accuracy: 1.0000
# Epoch 44/50
# 55/55 [==============================] - 0s 3ms/step - loss: 7.9583e-05 - accuracy: 1.0000
# Epoch 45/50
# 55/55 [==============================] - 0s 3ms/step - loss: 7.4604e-05 - accuracy: 1.0000
# Epoch 46/50
# 55/55 [==============================] - 0s 3ms/step - loss: 7.0110e-05 - accuracy: 1.0000
# Epoch 47/50
# 55/55 [==============================] - 0s 2ms/step - loss: 6.5888e-05 - accuracy: 1.0000
# Epoch 48/50
# 55/55 [==============================] - 0s 2ms/step - loss: 6.2062e-05 - accuracy: 1.0000
# Epoch 49/50
# 55/55 [==============================] - 0s 3ms/step - loss: 5.8471e-05 - accuracy: 1.0000
# Epoch 50/50
# 55/55 [==============================] - 0s 3ms/step - loss: 5.5151e-05 - accuracy: 1.0000

# %%
model_file = '%s_NCF_%d_%s.h5' % (dataset, latent_dim, str(dense_layers))
model.save(model_file, overwrite=True)

# %%
# %%time
from keras.models import load_model
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans

# this is a nice rock/oldies playlist
desired_user_id = 500
model_path = 'steam_video_NCF_8_[64, 32, 16, 8].h5'
print('using model: %s' % model_path)
model = load_model(model_path)
print('Loaded model!')

mlp_user_embedding_weights = (next(iter(filter(lambda x: x.name == 'mlp_user_embedding', model.layers))).get_weights())

# get the latent embedding for your desired user
user_latent_matrix = mlp_user_embedding_weights[0]
one_user_vector = user_latent_matrix[desired_user_id,:]
one_user_vector = np.reshape(one_user_vector, (1,32))

print('\nPerforming kmeans to find the nearest users/playlists...')
# get 100 similar users
# kmeans = KMeans(n_clusters=100, random_state=0, verbose=1).fit(user_latent_matrix)
kmeans = MiniBatchKMeans(n_clusters=100, random_state=0, verbose=1).fit(user_latent_matrix)
desired_user_label = kmeans.predict(one_user_vector)
user_label = kmeans.labels_
neighbors = []
for user_id, user_label in enumerate(user_label):
    # print('user_id:{0} user_label:{1}'.format(user_id, user_label))
    if user_label == desired_user_label:
        neighbors.append(user_id)
print('Found {0} neighbor users/playlists.'.format(len(neighbors)))
# Out:
# using model: steam_video_NCF_8_[64, 32, 16, 8].h5
# Loaded model!
#
# Performing kmeans to find the nearest users/playlists...
# Init 1/3 with method: k-means++
# Inertia for init 1/3: 18.117542
# Init 2/3 with method: k-means++
# Inertia for init 2/3: 17.414335
# Init 3/3 with method: k-means++
# Inertia for init 3/3: 18.221548
# Minibatch iteration 1/2800: mean batch inertia: 0.081265, ewa inertia: 0.081265
# Minibatch iteration 2/2800: mean batch inertia: 0.083734, ewa inertia: 0.081441
# Minibatch iteration 3/2800: mean batch inertia: 0.078911, ewa inertia: 0.081260
# Minibatch iteration 4/2800: mean batch inertia: 0.086899, ewa inertia: 0.081664
# Minibatch iteration 5/2800: mean batch inertia: 0.084520, ewa inertia: 0.081868
# Minibatch iteration 6/2800: mean batch inertia: 0.074568, ewa inertia: 0.081346
# Minibatch iteration 7/2800: mean batch inertia: 0.082659, ewa inertia: 0.081440
# Minibatch iteration 8/2800: mean batch inertia: 0.077227, ewa inertia: 0.081138
# Minibatch iteration 9/2800: mean batch inertia: 0.076634, ewa inertia: 0.080816
# [MiniBatchKMeans] Reassigning 11 cluster centers.
# Minibatch iteration 10/2800: mean batch inertia: 0.077882, ewa inertia: 0.080606
# Minibatch iteration 11/2800: mean batch inertia: 0.082142, ewa inertia: 0.080716
# Minibatch iteration 12/2800: mean batch inertia: 0.090867, ewa inertia: 0.081442
# Minibatch iteration 13/2800: mean batch inertia: 0.085457, ewa inertia: 0.081729
# Minibatch iteration 14/2800: mean batch inertia: 0.086226, ewa inertia: 0.082051
# Minibatch iteration 15/2800: mean batch inertia: 0.081439, ewa inertia: 0.082007
# Minibatch iteration 16/2800: mean batch inertia: 0.074812, ewa inertia: 0.081492
# Minibatch iteration 17/2800: mean batch inertia: 0.080538, ewa inertia: 0.081424
# Minibatch iteration 18/2800: mean batch inertia: 0.075736, ewa inertia: 0.081017
# Minibatch iteration 19/2800: mean batch inertia: 0.082537, ewa inertia: 0.081126
# Minibatch iteration 20/2800: mean batch inertia: 0.080257, ewa inertia: 0.081064
# Converged (lack of improvement in inertia) at iteration 20/2800
# Computing label assignment and total inertia
# Computing label assignment and total inertia
# user_id:0 user_label:85
# user_id:1 user_label:49
# user_id:2 user_label:6
# user_id:3 user_label:15
# user_id:4 user_label:19
# user_id:5 user_label:10
# user_id:6 user_label:15
# user_id:7 user_label:9
# user_id:8 user_label:6
# user_id:9 user_label:73
# user_id:10 user_label:45
# user_id:11 user_label:61
# user_id:12 user_label:49
# user_id:13 user_label:10
# user_id:14 user_label:80
# user_id:15 user_label:72
# user_id:16 user_label:96
# user_id:17 user_label:90
# user_id:18 user_label:99
# user_id:19 user_label:68
# user_id:20 user_label:36
# user_id:21 user_label:54
# user_id:22 user_label:2
# user_id:23 user_label:71
# user_id:24 user_label:15
# user_id:25 user_label:66
# user_id:26 user_label:46
# user_id:27 user_label:80
# user_id:28 user_label:15
# user_id:29 user_label:31
# user_id:30 user_label:85
# user_id:31 user_label:99
# user_id:32 user_label:54
# user_id:33 user_label:68
# user_id:34 user_label:7
# user_id:35 user_label:49
# user_id:36 user_label:25
# user_id:37 user_label:23
# user_id:38 user_label:96
# user_id:39 user_label:10
# user_id:40 user_label:13
# user_id:41 user_label:71
# user_id:42 user_label:71
# user_id:43 user_label:15
# user_id:44 user_label:49
# user_id:45 user_label:92
# user_id:46 user_label:10
# user_id:47 user_label:14
# user_id:48 user_label:36
# user_id:49 user_label:49
# user_id:50 user_label:10
# user_id:51 user_label:15
# user_id:52 user_label:37
# user_id:53 user_label:32
# user_id:54 user_label:50
# user_id:55 user_label:14
# user_id:56 user_label:99
# user_id:57 user_label:77
# user_id:58 user_label:72
# user_id:59 user_label:68
# user_id:60 user_label:13
# user_id:61 user_label:10
# user_id:62 user_label:31
# user_id:63 user_label:67
# user_id:64 user_label:13
# user_id:65 user_label:25
# user_id:66 user_label:13
# user_id:67 user_label:45
# user_id:68 user_label:2
# user_id:69 user_label:4
# user_id:70 user_label:45
# user_id:71 user_label:2
# user_id:72 user_label:48
# user_id:73 user_label:10
# user_id:74 user_label:19
# user_id:75 user_label:99
# user_id:76 user_label:61
# user_id:77 user_label:30
# user_id:78 user_label:49
# user_id:79 user_label:10
# user_id:80 user_label:40
# user_id:81 user_label:63
# user_id:82 user_label:85
# user_id:83 user_label:10
# user_id:84 user_label:8
# user_id:85 user_label:73
# user_id:86 user_label:27
# user_id:87 user_label:54
# user_id:88 user_label:10
# user_id:89 user_label:49
# user_id:90 user_label:49
# user_id:91 user_label:49
# user_id:92 user_label:31
# user_id:93 user_label:12
# user_id:94 user_label:23
# user_id:95 user_label:40
# user_id:96 user_label:15
# user_id:97 user_label:0
# user_id:98 user_label:10
# user_id:99 user_label:61
# user_id:100 user_label:45
# user_id:101 user_label:52
# user_id:102 user_label:25
# user_id:103 user_label:19
# user_id:104 user_label:99
# user_id:105 user_label:61
# user_id:106 user_label:15
# user_id:107 user_label:28
# user_id:108 user_label:67
# user_id:109 user_label:49
# user_id:110 user_label:10
# user_id:111 user_label:96
# user_id:112 user_label:73
# user_id:113 user_label:77
# user_id:114 user_label:99
# user_id:115 user_label:55
# user_id:116 user_label:82
# user_id:117 user_label:49
# user_id:118 user_label:9
# user_id:119 user_label:80
# user_id:120 user_label:72
# user_id:121 user_label:73
# user_id:122 user_label:99
# user_id:123 user_label:27
# user_id:124 user_label:89
# user_id:125 user_label:61
# user_id:126 user_label:49
# user_id:127 user_label:58
# user_id:128 user_label:2
# user_id:129 user_label:43
# user_id:130 user_label:3
# user_id:131 user_label:99
# user_id:132 user_label:36
# user_id:133 user_label:78
# user_id:134 user_label:76
# user_id:135 user_label:15
# user_id:136 user_label:43
# user_id:137 user_label:76
# user_id:138 user_label:66
# user_id:139 user_label:82
# user_id:140 user_label:85
# user_id:141 user_label:9
# user_id:142 user_label:1
# user_id:143 user_label:71
# user_id:144 user_label:35
# user_id:145 user_label:40
# user_id:146 user_label:10
# user_id:147 user_label:72
# user_id:148 user_label:81
# user_id:149 user_label:67
# user_id:150 user_label:55
# user_id:151 user_label:54
# user_id:152 user_label:54
# user_id:153 user_label:99
# user_id:154 user_label:48
# user_id:155 user_label:96
# user_id:156 user_label:29
# user_id:157 user_label:6
# user_id:158 user_label:49
# user_id:159 user_label:31
# user_id:160 user_label:56
# user_id:161 user_label:27
# user_id:162 user_label:36
# user_id:163 user_label:19
# user_id:164 user_label:15
# user_id:165 user_label:13
# user_id:166 user_label:61
# user_id:167 user_label:73
# user_id:168 user_label:61
# user_id:169 user_label:11
# user_id:170 user_label:2
# user_id:171 user_label:97
# user_id:172 user_label:11
# user_id:173 user_label:74
# user_id:174 user_label:61
# user_id:175 user_label:10
# user_id:176 user_label:11
# user_id:177 user_label:49
# user_id:178 user_label:13
# user_id:179 user_label:73
# user_id:180 user_label:73
# user_id:181 user_label:1
# user_id:182 user_label:71
# user_id:183 user_label:96
# user_id:184 user_label:51
# user_id:185 user_label:7
# user_id:186 user_label:56
# user_id:187 user_label:99
# user_id:188 user_label:49
# user_id:189 user_label:99
# user_id:190 user_label:54
# user_id:191 user_label:25
# user_id:192 user_label:76
# user_id:193 user_label:25
# user_id:194 user_label:12
# user_id:195 user_label:99
# user_id:196 user_label:31
# user_id:197 user_label:2
# user_id:198 user_label:77
# user_id:199 user_label:48
# user_id:200 user_label:49
# user_id:201 user_label:56
# user_id:202 user_label:99
# user_id:203 user_label:80
# user_id:204 user_label:21
# user_id:205 user_label:82
# user_id:206 user_label:6
# user_id:207 user_label:15
# user_id:208 user_label:38
# user_id:209 user_label:9
# user_id:210 user_label:19
# user_id:211 user_label:99
# user_id:212 user_label:15
# user_id:213 user_label:23
# user_id:214 user_label:53
# user_id:215 user_label:10
# user_id:216 user_label:72
# user_id:217 user_label:23
# user_id:218 user_label:73
# user_id:219 user_label:73
# user_id:220 user_label:15
# user_id:221 user_label:25
# user_id:222 user_label:19
# user_id:223 user_label:25
# user_id:224 user_label:6
# user_id:225 user_label:43
# user_id:226 user_label:2
# user_id:227 user_label:10
# user_id:228 user_label:1
# user_id:229 user_label:49
# user_id:230 user_label:49
# user_id:231 user_label:87
# user_id:232 user_label:31
# user_id:233 user_label:72
# user_id:234 user_label:36
# user_id:235 user_label:96
# user_id:236 user_label:10
# user_id:237 user_label:73
# user_id:238 user_label:17
# user_id:239 user_label:10
# user_id:240 user_label:49
# user_id:241 user_label:73
# user_id:242 user_label:36
# user_id:243 user_label:49
# user_id:244 user_label:92
# user_id:245 user_label:15
# user_id:246 user_label:5
# user_id:247 user_label:52
# user_id:248 user_label:49
# user_id:249 user_label:81
# user_id:250 user_label:10
# user_id:251 user_label:40
# user_id:252 user_label:76
# user_id:253 user_label:99
# user_id:254 user_label:45
# user_id:255 user_label:71
# user_id:256 user_label:99
# user_id:257 user_label:27
# user_id:258 user_label:77
# user_id:259 user_label:91
# user_id:260 user_label:74
# user_id:261 user_label:87
# user_id:262 user_label:99
# user_id:263 user_label:13
# user_id:264 user_label:34
# user_id:265 user_label:92
# user_id:266 user_label:62
# user_id:267 user_label:49
# user_id:268 user_label:29
# user_id:269 user_label:49
# user_id:270 user_label:60
# user_id:271 user_label:10
# user_id:272 user_label:87
# user_id:273 user_label:1
# user_id:274 user_label:72
# user_id:275 user_label:0
# user_id:276 user_label:54
# user_id:277 user_label:62
# user_id:278 user_label:71
# user_id:279 user_label:62
# user_id:280 user_label:49
# user_id:281 user_label:13
# user_id:282 user_label:77
# user_id:283 user_label:99
# user_id:284 user_label:2
# user_id:285 user_label:7
# user_id:286 user_label:45
# user_id:287 user_label:87
# user_id:288 user_label:45
# user_id:289 user_label:68
# user_id:290 user_label:54
# user_id:291 user_label:71
# user_id:292 user_label:92
# user_id:293 user_label:31
# user_id:294 user_label:13
# user_id:295 user_label:72
# user_id:296 user_label:85
# user_id:297 user_label:69
# user_id:298 user_label:19
# user_id:299 user_label:68
# user_id:300 user_label:71
# user_id:301 user_label:71
# user_id:302 user_label:32
# user_id:303 user_label:39
# user_id:304 user_label:13
# user_id:305 user_label:19
# user_id:306 user_label:49
# user_id:307 user_label:95
# user_id:308 user_label:38
# user_id:309 user_label:30
# user_id:310 user_label:99
# user_id:311 user_label:23
# user_id:312 user_label:85
# user_id:313 user_label:71
# user_id:314 user_label:49
# user_id:315 user_label:10
# user_id:316 user_label:23
# user_id:317 user_label:99
# user_id:318 user_label:19
# user_id:319 user_label:99
# user_id:320 user_label:54
# user_id:321 user_label:61
# user_id:322 user_label:7
# user_id:323 user_label:54
# user_id:324 user_label:54
# user_id:325 user_label:99
# user_id:326 user_label:45
# user_id:327 user_label:0
# user_id:328 user_label:25
# user_id:329 user_label:40
# user_id:330 user_label:41
# user_id:331 user_label:11
# user_id:332 user_label:25
# user_id:333 user_label:76
# user_id:334 user_label:76
# user_id:335 user_label:18
# user_id:336 user_label:23
# user_id:337 user_label:9
# user_id:338 user_label:68
# user_id:339 user_label:3
# user_id:340 user_label:80
# user_id:341 user_label:9
# user_id:342 user_label:67
# user_id:343 user_label:15
# user_id:344 user_label:89
# user_id:345 user_label:45
# user_id:346 user_label:45
# user_id:347 user_label:2
# user_id:348 user_label:45
# user_id:349 user_label:9
# user_id:350 user_label:45
# user_id:351 user_label:85
# user_id:352 user_label:24
# user_id:353 user_label:96
# user_id:354 user_label:49
# user_id:355 user_label:25
# user_id:356 user_label:61
# user_id:357 user_label:54
# user_id:358 user_label:25
# user_id:359 user_label:36
# user_id:360 user_label:25
# user_id:361 user_label:97
# user_id:362 user_label:96
# user_id:363 user_label:10
# user_id:364 user_label:31
# user_id:365 user_label:99
# user_id:366 user_label:99
# user_id:367 user_label:11
# user_id:368 user_label:45
# user_id:369 user_label:11
# user_id:370 user_label:71
# user_id:371 user_label:2
# user_id:372 user_label:61
# user_id:373 user_label:50
# user_id:374 user_label:49
# user_id:375 user_label:45
# user_id:376 user_label:46
# user_id:377 user_label:2
# user_id:378 user_label:99
# user_id:379 user_label:96
# user_id:380 user_label:83
# user_id:381 user_label:13
# user_id:382 user_label:9
# user_id:383 user_label:51
# user_id:384 user_label:57
# user_id:385 user_label:13
# user_id:386 user_label:77
# user_id:387 user_label:71
# user_id:388 user_label:76
# user_id:389 user_label:72
# user_id:390 user_label:49
# user_id:391 user_label:54
# user_id:392 user_label:15
# user_id:393 user_label:49
# user_id:394 user_label:71
# user_id:395 user_label:76
# user_id:396 user_label:62
# user_id:397 user_label:6
# user_id:398 user_label:45
# user_id:399 user_label:15
# user_id:400 user_label:40
# user_id:401 user_label:73
# user_id:402 user_label:72
# user_id:403 user_label:23
# user_id:404 user_label:10
# user_id:405 user_label:99
# user_id:406 user_label:12
# user_id:407 user_label:13
# user_id:408 user_label:76
# user_id:409 user_label:76
# user_id:410 user_label:67
# user_id:411 user_label:3
# user_id:412 user_label:2
# user_id:413 user_label:40
# user_id:414 user_label:19
# user_id:415 user_label:99
# user_id:416 user_label:13
# user_id:417 user_label:10
# user_id:418 user_label:11
# user_id:419 user_label:71
# user_id:420 user_label:72
# user_id:421 user_label:77
# user_id:422 user_label:73
# user_id:423 user_label:52
# user_id:424 user_label:10
# user_id:425 user_label:25
# user_id:426 user_label:72
# user_id:427 user_label:10
# user_id:428 user_label:40
# user_id:429 user_label:23
# user_id:430 user_label:43
# user_id:431 user_label:10
# user_id:432 user_label:11
# user_id:433 user_label:99
# user_id:434 user_label:80
# user_id:435 user_label:76
# user_id:436 user_label:71
# user_id:437 user_label:13
# user_id:438 user_label:76
# user_id:439 user_label:2
# user_id:440 user_label:38
# user_id:441 user_label:71
# user_id:442 user_label:73
# user_id:443 user_label:51
# user_id:444 user_label:45
# user_id:445 user_label:76
# user_id:446 user_label:10
# user_id:447 user_label:76
# user_id:448 user_label:72
# user_id:449 user_label:96
# user_id:450 user_label:96
# user_id:451 user_label:31
# user_id:452 user_label:12
# user_id:453 user_label:48
# user_id:454 user_label:49
# user_id:455 user_label:4
# user_id:456 user_label:71
# user_id:457 user_label:49
# user_id:458 user_label:13
# user_id:459 user_label:19
# user_id:460 user_label:13
# user_id:461 user_label:33
# user_id:462 user_label:27
# user_id:463 user_label:68
# user_id:464 user_label:10
# user_id:465 user_label:10
# user_id:466 user_label:10
# user_id:467 user_label:72
# user_id:468 user_label:80
# user_id:469 user_label:54
# user_id:470 user_label:10
# user_id:471 user_label:39
# user_id:472 user_label:40
# user_id:473 user_label:4
# user_id:474 user_label:19
# user_id:475 user_label:85
# user_id:476 user_label:74
# user_id:477 user_label:10
# user_id:478 user_label:10
# user_id:479 user_label:96
# user_id:480 user_label:49
# user_id:481 user_label:69
# user_id:482 user_label:49
# user_id:483 user_label:36
# user_id:484 user_label:10
# user_id:485 user_label:54
# user_id:486 user_label:45
# user_id:487 user_label:49
# user_id:488 user_label:86
# user_id:489 user_label:15
# user_id:490 user_label:23
# user_id:491 user_label:31
# user_id:492 user_label:80
# user_id:493 user_label:15
# user_id:494 user_label:61
# user_id:495 user_label:71
# user_id:496 user_label:25
# user_id:497 user_label:54
# user_id:498 user_label:45
# user_id:499 user_label:49
# user_id:500 user_label:76
# user_id:501 user_label:64
# user_id:502 user_label:23
# user_id:503 user_label:27
# user_id:504 user_label:76
# user_id:505 user_label:76
# user_id:506 user_label:87
# user_id:507 user_label:85
# user_id:508 user_label:36
# user_id:509 user_label:53
# user_id:510 user_label:96
# user_id:511 user_label:4
# user_id:512 user_label:45
# user_id:513 user_label:45
# user_id:514 user_label:93
# user_id:515 user_label:53
# user_id:516 user_label:10
# user_id:517 user_label:55
# user_id:518 user_label:24
# user_id:519 user_label:40
# user_id:520 user_label:28
# user_id:521 user_label:88
# user_id:522 user_label:72
# user_id:523 user_label:55
# user_id:524 user_label:13
# user_id:525 user_label:1
# user_id:526 user_label:25
# user_id:527 user_label:68
# user_id:528 user_label:35
# user_id:529 user_label:30
# user_id:530 user_label:14
# user_id:531 user_label:71
# user_id:532 user_label:68
# user_id:533 user_label:72
# user_id:534 user_label:76
# user_id:535 user_label:46
# user_id:536 user_label:19
# user_id:537 user_label:55
# user_id:538 user_label:13
# user_id:539 user_label:67
# user_id:540 user_label:99
# user_id:541 user_label:31
# user_id:542 user_label:83
# user_id:543 user_label:2
# user_id:544 user_label:44
# user_id:545 user_label:7
# user_id:546 user_label:45
# user_id:547 user_label:45
# user_id:548 user_label:45
# user_id:549 user_label:10
# user_id:550 user_label:69
# user_id:551 user_label:85
# user_id:552 user_label:13
# user_id:553 user_label:99
# user_id:554 user_label:23
# user_id:555 user_label:10
# user_id:556 user_label:20
# user_id:557 user_label:73
# user_id:558 user_label:72
# user_id:559 user_label:53
# user_id:560 user_label:63
# user_id:561 user_label:19
# user_id:562 user_label:98
# user_id:563 user_label:62
# user_id:564 user_label:40
# user_id:565 user_label:40
# user_id:566 user_label:12
# user_id:567 user_label:49
# user_id:568 user_label:35
# user_id:569 user_label:12
# user_id:570 user_label:27
# user_id:571 user_label:96
# user_id:572 user_label:39
# user_id:573 user_label:73
# user_id:574 user_label:38
# user_id:575 user_label:61
# user_id:576 user_label:76
# user_id:577 user_label:76
# user_id:578 user_label:10
# user_id:579 user_label:22
# user_id:580 user_label:53
# user_id:581 user_label:68
# user_id:582 user_label:48
# user_id:583 user_label:39
# user_id:584 user_label:7
# user_id:585 user_label:30
# user_id:586 user_label:7
# user_id:587 user_label:71
# user_id:588 user_label:67
# user_id:589 user_label:31
# user_id:590 user_label:76
# user_id:591 user_label:49
# user_id:592 user_label:49
# user_id:593 user_label:45
# user_id:594 user_label:10
# user_id:595 user_label:49
# user_id:596 user_label:99
# user_id:597 user_label:12
# user_id:598 user_label:85
# user_id:599 user_label:54
# user_id:600 user_label:74
# user_id:601 user_label:85
# user_id:602 user_label:99
# user_id:603 user_label:99
# user_id:604 user_label:5
# user_id:605 user_label:23
# user_id:606 user_label:58
# user_id:607 user_label:47
# user_id:608 user_label:76
# user_id:609 user_label:13
# user_id:610 user_label:10
# user_id:611 user_label:74
# user_id:612 user_label:72
# user_id:613 user_label:15
# user_id:614 user_label:23
# user_id:615 user_label:9
# user_id:616 user_label:32
# user_id:617 user_label:2
# user_id:618 user_label:32
# user_id:619 user_label:7
# user_id:620 user_label:80
# user_id:621 user_label:32
# user_id:622 user_label:89
# user_id:623 user_label:66
# user_id:624 user_label:25
# user_id:625 user_label:32
# user_id:626 user_label:72
# user_id:627 user_label:95
# user_id:628 user_label:31
# user_id:629 user_label:32
# user_id:630 user_label:17
# user_id:631 user_label:31
# user_id:632 user_label:91
# user_id:633 user_label:91
# user_id:634 user_label:24
# user_id:635 user_label:57
# user_id:636 user_label:42
# user_id:637 user_label:31
# user_id:638 user_label:57
# user_id:639 user_label:37
# user_id:640 user_label:9
# user_id:641 user_label:55
# user_id:642 user_label:7
# user_id:643 user_label:94
# user_id:644 user_label:19
# user_id:645 user_label:80
# user_id:646 user_label:3
# user_id:647 user_label:32
# user_id:648 user_label:65
# user_id:649 user_label:28
# user_id:650 user_label:32
# user_id:651 user_label:14
# user_id:652 user_label:94
# user_id:653 user_label:87
# user_id:654 user_label:3
# user_id:655 user_label:2
# user_id:656 user_label:97
# user_id:657 user_label:91
# user_id:658 user_label:54
# user_id:659 user_label:68
# user_id:660 user_label:6
# user_id:661 user_label:32
# user_id:662 user_label:94
# user_id:663 user_label:28
# user_id:664 user_label:46
# user_id:665 user_label:16
# user_id:666 user_label:16
# user_id:667 user_label:97
# user_id:668 user_label:91
# user_id:669 user_label:6
# user_id:670 user_label:2
# user_id:671 user_label:54
# user_id:672 user_label:31
# user_id:673 user_label:74
# user_id:674 user_label:89
# user_id:675 user_label:31
# user_id:676 user_label:32
# user_id:677 user_label:16
# user_id:678 user_label:80
# user_id:679 user_label:60
# user_id:680 user_label:91
# user_id:681 user_label:90
# user_id:682 user_label:38
# user_id:683 user_label:89
# user_id:684 user_label:87
# user_id:685 user_label:74
# user_id:686 user_label:11
# user_id:687 user_label:90
# user_id:688 user_label:31
# user_id:689 user_label:17
# user_id:690 user_label:32
# user_id:691 user_label:78
# user_id:692 user_label:7
# user_id:693 user_label:60
# user_id:694 user_label:14
# user_id:695 user_label:95
# user_id:696 user_label:31
# user_id:697 user_label:16
# user_id:698 user_label:57
# user_id:699 user_label:31
# user_id:700 user_label:7
# user_id:701 user_label:89
# user_id:702 user_label:25
# user_id:703 user_label:28
# user_id:704 user_label:74
# user_id:705 user_label:17
# user_id:706 user_label:5
# user_id:707 user_label:95
# user_id:708 user_label:3
# user_id:709 user_label:87
# user_id:710 user_label:16
# user_id:711 user_label:95
# user_id:712 user_label:4
# user_id:713 user_label:46
# user_id:714 user_label:57
# user_id:715 user_label:24
# user_id:716 user_label:78
# user_id:717 user_label:16
# user_id:718 user_label:94
# user_id:719 user_label:37
# user_id:720 user_label:78
# user_id:721 user_label:1
# user_id:722 user_label:94
# user_id:723 user_label:3
# user_id:724 user_label:3
# user_id:725 user_label:57
# user_id:726 user_label:74
# user_id:727 user_label:6
# user_id:728 user_label:32
# user_id:729 user_label:37
# user_id:730 user_label:89
# user_id:731 user_label:2
# user_id:732 user_label:78
# user_id:733 user_label:17
# user_id:734 user_label:11
# user_id:735 user_label:23
# user_id:736 user_label:91
# user_id:737 user_label:54
# user_id:738 user_label:6
# user_id:739 user_label:90
# user_id:740 user_label:95
# user_id:741 user_label:16
# user_id:742 user_label:55
# user_id:743 user_label:87
# user_id:744 user_label:77
# user_id:745 user_label:4
# user_id:746 user_label:55
# user_id:747 user_label:5
# user_id:748 user_label:4
# user_id:749 user_label:89
# user_id:750 user_label:78
# user_id:751 user_label:90
# user_id:752 user_label:97
# user_id:753 user_label:25
# user_id:754 user_label:23
# user_id:755 user_label:12
# user_id:756 user_label:6
# user_id:757 user_label:15
# user_id:758 user_label:74
# user_id:759 user_label:90
# user_id:760 user_label:97
# user_id:761 user_label:16
# user_id:762 user_label:32
# user_id:763 user_label:95
# user_id:764 user_label:3
# user_id:765 user_label:72
# user_id:766 user_label:6
# user_id:767 user_label:94
# user_id:768 user_label:16
# user_id:769 user_label:91
# user_id:770 user_label:90
# user_id:771 user_label:6
# user_id:772 user_label:16
# user_id:773 user_label:5
# user_id:774 user_label:9
# user_id:775 user_label:17
# user_id:776 user_label:57
# user_id:777 user_label:6
# user_id:778 user_label:16
# user_id:779 user_label:14
# user_id:780 user_label:32
# user_id:781 user_label:91
# user_id:782 user_label:4
# user_id:783 user_label:14
# user_id:784 user_label:90
# user_id:785 user_label:17
# user_id:786 user_label:31
# user_id:787 user_label:6
# user_id:788 user_label:28
# user_id:789 user_label:77
# user_id:790 user_label:14
# user_id:791 user_label:95
# user_id:792 user_label:95
# user_id:793 user_label:24
# user_id:794 user_label:54
# user_id:795 user_label:17
# user_id:796 user_label:17
# user_id:797 user_label:79
# user_id:798 user_label:95
# user_id:799 user_label:14
# user_id:800 user_label:16
# user_id:801 user_label:91
# user_id:802 user_label:38
# user_id:803 user_label:95
# user_id:804 user_label:24
# user_id:805 user_label:1
# user_id:806 user_label:31
# user_id:807 user_label:97
# user_id:808 user_label:3
# user_id:809 user_label:38
# user_id:810 user_label:32
# user_id:811 user_label:58
# user_id:812 user_label:4
# user_id:813 user_label:17
# user_id:814 user_label:78
# user_id:815 user_label:37
# user_id:816 user_label:16
# user_id:817 user_label:89
# user_id:818 user_label:1
# user_id:819 user_label:32
# user_id:820 user_label:32
# user_id:821 user_label:7
# user_id:822 user_label:74
# user_id:823 user_label:54
# user_id:824 user_label:6
# user_id:825 user_label:32
# user_id:826 user_label:1
# user_id:827 user_label:46
# user_id:828 user_label:6
# user_id:829 user_label:57
# user_id:830 user_label:94
# user_id:831 user_label:74
# user_id:832 user_label:7
# user_id:833 user_label:54
# user_id:834 user_label:89
# user_id:835 user_label:28
# user_id:836 user_label:37
# user_id:837 user_label:17
# user_id:838 user_label:31
# user_id:839 user_label:95
# user_id:840 user_label:24
# user_id:841 user_label:90
# user_id:842 user_label:90
# user_id:843 user_label:74
# user_id:844 user_label:4
# user_id:845 user_label:3
# user_id:846 user_label:31
# user_id:847 user_label:3
# user_id:848 user_label:68
# user_id:849 user_label:4
# user_id:850 user_label:11
# user_id:851 user_label:94
# user_id:852 user_label:57
# user_id:853 user_label:89
# user_id:854 user_label:24
# user_id:855 user_label:97
# user_id:856 user_label:54
# user_id:857 user_label:57
# user_id:858 user_label:17
# user_id:859 user_label:15
# user_id:860 user_label:87
# user_id:861 user_label:74
# user_id:862 user_label:87
# user_id:863 user_label:17
# user_id:864 user_label:4
# user_id:865 user_label:46
# user_id:866 user_label:97
# user_id:867 user_label:88
# user_id:868 user_label:91
# user_id:869 user_label:16
# user_id:870 user_label:28
# user_id:871 user_label:9
# user_id:872 user_label:17
# user_id:873 user_label:7
# user_id:874 user_label:58
# user_id:875 user_label:31
# user_id:876 user_label:80
# user_id:877 user_label:84
# user_id:878 user_label:14
# user_id:879 user_label:87
# user_id:880 user_label:54
# user_id:881 user_label:55
# user_id:882 user_label:2
# user_id:883 user_label:55
# user_id:884 user_label:72
# user_id:885 user_label:91
# user_id:886 user_label:38
# user_id:887 user_label:90
# user_id:888 user_label:15
# user_id:889 user_label:12
# user_id:890 user_label:4
# user_id:891 user_label:32
# user_id:892 user_label:55
# user_id:893 user_label:6
# user_id:894 user_label:91
# user_id:895 user_label:95
# user_id:896 user_label:37
# user_id:897 user_label:77
# user_id:898 user_label:89
# user_id:899 user_label:74
# user_id:900 user_label:89
# user_id:901 user_label:95
# user_id:902 user_label:12
# user_id:903 user_label:3
# user_id:904 user_label:1
# user_id:905 user_label:9
# user_id:906 user_label:32
# user_id:907 user_label:6
# user_id:908 user_label:74
# user_id:909 user_label:78
# user_id:910 user_label:16
# user_id:911 user_label:78
# user_id:912 user_label:72
# user_id:913 user_label:90
# user_id:914 user_label:6
# user_id:915 user_label:87
# user_id:916 user_label:55
# user_id:917 user_label:16
# user_id:918 user_label:89
# user_id:919 user_label:72
# user_id:920 user_label:3
# user_id:921 user_label:6
# user_id:922 user_label:16
# user_id:923 user_label:5
# user_id:924 user_label:88
# user_id:925 user_label:14
# user_id:926 user_label:9
# user_id:927 user_label:24
# user_id:928 user_label:97
# user_id:929 user_label:95
# user_id:930 user_label:94
# user_id:931 user_label:11
# user_id:932 user_label:89
# user_id:933 user_label:89
# user_id:934 user_label:95
# user_id:935 user_label:54
# user_id:936 user_label:55
# user_id:937 user_label:23
# user_id:938 user_label:87
# user_id:939 user_label:31
# user_id:940 user_label:3
# user_id:941 user_label:91
# user_id:942 user_label:95
# user_id:943 user_label:90
# user_id:944 user_label:3
# user_id:945 user_label:28
# user_id:946 user_label:89
# user_id:947 user_label:3
# user_id:948 user_label:16
# user_id:949 user_label:57
# user_id:950 user_label:25
# user_id:951 user_label:77
# user_id:952 user_label:2
# user_id:953 user_label:17
# user_id:954 user_label:7
# user_id:955 user_label:16
# user_id:956 user_label:7
# user_id:957 user_label:90
# user_id:958 user_label:31
# user_id:959 user_label:24
# user_id:960 user_label:77
# user_id:961 user_label:78
# user_id:962 user_label:90
# user_id:963 user_label:31
# user_id:964 user_label:16
# user_id:965 user_label:9
# user_id:966 user_label:97
# user_id:967 user_label:54
# user_id:968 user_label:91
# user_id:969 user_label:91
# user_id:970 user_label:4
# user_id:971 user_label:14
# user_id:972 user_label:5
# user_id:973 user_label:4
# user_id:974 user_label:95
# user_id:975 user_label:55
# user_id:976 user_label:6
# user_id:977 user_label:24
# user_id:978 user_label:90
# user_id:979 user_label:54
# user_id:980 user_label:17
# user_id:981 user_label:97
# user_id:982 user_label:74
# user_id:983 user_label:3
# user_id:984 user_label:17
# user_id:985 user_label:54
# user_id:986 user_label:23
# user_id:987 user_label:4
# user_id:988 user_label:72
# user_id:989 user_label:38
# user_id:990 user_label:97
# user_id:991 user_label:17
# user_id:992 user_label:12
# user_id:993 user_label:74
# user_id:994 user_label:88
# user_id:995 user_label:12
# user_id:996 user_label:97
# user_id:997 user_label:31
# user_id:998 user_label:12
# user_id:999 user_label:74
# user_id:1000 user_label:4
# user_id:1001 user_label:7
# user_id:1002 user_label:38
# user_id:1003 user_label:31
# user_id:1004 user_label:14
# user_id:1005 user_label:89
# user_id:1006 user_label:5
# user_id:1007 user_label:59
# user_id:1008 user_label:97
# user_id:1009 user_label:7
# user_id:1010 user_label:58
# user_id:1011 user_label:31
# user_id:1012 user_label:2
# user_id:1013 user_label:94
# user_id:1014 user_label:31
# user_id:1015 user_label:94
# user_id:1016 user_label:9
# user_id:1017 user_label:17
# user_id:1018 user_label:37
# user_id:1019 user_label:89
# user_id:1020 user_label:11
# user_id:1021 user_label:15
# user_id:1022 user_label:37
# user_id:1023 user_label:17
# user_id:1024 user_label:9
# user_id:1025 user_label:89
# user_id:1026 user_label:89
# user_id:1027 user_label:28
# user_id:1028 user_label:3
# user_id:1029 user_label:25
# user_id:1030 user_label:91
# user_id:1031 user_label:87
# user_id:1032 user_label:89
# user_id:1033 user_label:88
# user_id:1034 user_label:1
# user_id:1035 user_label:15
# user_id:1036 user_label:7
# user_id:1037 user_label:14
# user_id:1038 user_label:74
# user_id:1039 user_label:12
# user_id:1040 user_label:74
# user_id:1041 user_label:1
# user_id:1042 user_label:1
# user_id:1043 user_label:16
# user_id:1044 user_label:90
# user_id:1045 user_label:54
# user_id:1046 user_label:58
# user_id:1047 user_label:32
# user_id:1048 user_label:31
# user_id:1049 user_label:58
# user_id:1050 user_label:7
# user_id:1051 user_label:89
# user_id:1052 user_label:23
# user_id:1053 user_label:14
# user_id:1054 user_label:17
# user_id:1055 user_label:54
# user_id:1056 user_label:17
# user_id:1057 user_label:31
# user_id:1058 user_label:4
# user_id:1059 user_label:5
# user_id:1060 user_label:80
# user_id:1061 user_label:89
# user_id:1062 user_label:94
# user_id:1063 user_label:32
# user_id:1064 user_label:55
# user_id:1065 user_label:31
# user_id:1066 user_label:80
# user_id:1067 user_label:28
# user_id:1068 user_label:3
# user_id:1069 user_label:1
# user_id:1070 user_label:28
# user_id:1071 user_label:37
# user_id:1072 user_label:1
# user_id:1073 user_label:97
# user_id:1074 user_label:6
# user_id:1075 user_label:54
# user_id:1076 user_label:78
# user_id:1077 user_label:7
# user_id:1078 user_label:89
# user_id:1079 user_label:54
# user_id:1080 user_label:28
# user_id:1081 user_label:54
# user_id:1082 user_label:24
# user_id:1083 user_label:37
# user_id:1084 user_label:2
# user_id:1085 user_label:16
# user_id:1086 user_label:7
# user_id:1087 user_label:3
# user_id:1088 user_label:74
# user_id:1089 user_label:12
# user_id:1090 user_label:94
# user_id:1091 user_label:4
# user_id:1092 user_label:60
# user_id:1093 user_label:74
# user_id:1094 user_label:1
# user_id:1095 user_label:74
# user_id:1096 user_label:80
# user_id:1097 user_label:16
# user_id:1098 user_label:1
# user_id:1099 user_label:46
# user_id:1100 user_label:14
# user_id:1101 user_label:94
# user_id:1102 user_label:97
# user_id:1103 user_label:72
# user_id:1104 user_label:89
# user_id:1105 user_label:90
# user_id:1106 user_label:28
# user_id:1107 user_label:6
# user_id:1108 user_label:14
# user_id:1109 user_label:10
# user_id:1110 user_label:57
# user_id:1111 user_label:31
# user_id:1112 user_label:94
# user_id:1113 user_label:38
# user_id:1114 user_label:97
# user_id:1115 user_label:77
# user_id:1116 user_label:58
# user_id:1117 user_label:95
# user_id:1118 user_label:4
# user_id:1119 user_label:78
# user_id:1120 user_label:91
# user_id:1121 user_label:4
# user_id:1122 user_label:3
# user_id:1123 user_label:9
# user_id:1124 user_label:46
# user_id:1125 user_label:17
# user_id:1126 user_label:94
# user_id:1127 user_label:95
# user_id:1128 user_label:94
# user_id:1129 user_label:95
# user_id:1130 user_label:16
# user_id:1131 user_label:55
# user_id:1132 user_label:32
# user_id:1133 user_label:55
# user_id:1134 user_label:80
# user_id:1135 user_label:5
# user_id:1136 user_label:24
# user_id:1137 user_label:37
# user_id:1138 user_label:58
# user_id:1139 user_label:74
# user_id:1140 user_label:28
# user_id:1141 user_label:94
# user_id:1142 user_label:14
# user_id:1143 user_label:89
# user_id:1144 user_label:14
# user_id:1145 user_label:95
# user_id:1146 user_label:54
# user_id:1147 user_label:16
# user_id:1148 user_label:91
# user_id:1149 user_label:7
# user_id:1150 user_label:94
# user_id:1151 user_label:97
# user_id:1152 user_label:16
# user_id:1153 user_label:6
# user_id:1154 user_label:54
# user_id:1155 user_label:88
# user_id:1156 user_label:28
# user_id:1157 user_label:90
# user_id:1158 user_label:17
# user_id:1159 user_label:97
# user_id:1160 user_label:90
# user_id:1161 user_label:28
# user_id:1162 user_label:91
# user_id:1163 user_label:78
# user_id:1164 user_label:89
# user_id:1165 user_label:9
# user_id:1166 user_label:17
# user_id:1167 user_label:4
# user_id:1168 user_label:4
# user_id:1169 user_label:89
# user_id:1170 user_label:1
# user_id:1171 user_label:90
# user_id:1172 user_label:57
# user_id:1173 user_label:38
# user_id:1174 user_label:37
# user_id:1175 user_label:38
# user_id:1176 user_label:74
# user_id:1177 user_label:16
# user_id:1178 user_label:4
# user_id:1179 user_label:74
# user_id:1180 user_label:32
# user_id:1181 user_label:4
# user_id:1182 user_label:54
# user_id:1183 user_label:17
# user_id:1184 user_label:24
# user_id:1185 user_label:31
# user_id:1186 user_label:35
# user_id:1187 user_label:32
# user_id:1188 user_label:89
# user_id:1189 user_label:25
# user_id:1190 user_label:74
# user_id:1191 user_label:14
# user_id:1192 user_label:95
# user_id:1193 user_label:1
# user_id:1194 user_label:54
# user_id:1195 user_label:89
# user_id:1196 user_label:91
# user_id:1197 user_label:38
# user_id:1198 user_label:77
# user_id:1199 user_label:54
# user_id:1200 user_label:14
# user_id:1201 user_label:38
# user_id:1202 user_label:4
# user_id:1203 user_label:74
# user_id:1204 user_label:5
# user_id:1205 user_label:91
# user_id:1206 user_label:90
# user_id:1207 user_label:7
# user_id:1208 user_label:7
# user_id:1209 user_label:4
# user_id:1210 user_label:3
# user_id:1211 user_label:17
# user_id:1212 user_label:12
# user_id:1213 user_label:32
# user_id:1214 user_label:16
# user_id:1215 user_label:37
# user_id:1216 user_label:90
# user_id:1217 user_label:6
# user_id:1218 user_label:91
# user_id:1219 user_label:12
# user_id:1220 user_label:2
# user_id:1221 user_label:11
# user_id:1222 user_label:72
# user_id:1223 user_label:12
# user_id:1224 user_label:55
# user_id:1225 user_label:16
# user_id:1226 user_label:24
# user_id:1227 user_label:14
# user_id:1228 user_label:95
# user_id:1229 user_label:7
# user_id:1230 user_label:55
# user_id:1231 user_label:57
# user_id:1232 user_label:74
# user_id:1233 user_label:16
# user_id:1234 user_label:16
# user_id:1235 user_label:11
# user_id:1236 user_label:31
# user_id:1237 user_label:5
# user_id:1238 user_label:3
# user_id:1239 user_label:91
# user_id:1240 user_label:54
# user_id:1241 user_label:2
# user_id:1242 user_label:2
# user_id:1243 user_label:54
# user_id:1244 user_label:5
# user_id:1245 user_label:35
# user_id:1246 user_label:95
# user_id:1247 user_label:95
# user_id:1248 user_label:80
# user_id:1249 user_label:6
# user_id:1250 user_label:55
# user_id:1251 user_label:14
# user_id:1252 user_label:95
# user_id:1253 user_label:74
# user_id:1254 user_label:95
# user_id:1255 user_label:91
# user_id:1256 user_label:95
# user_id:1257 user_label:90
# user_id:1258 user_label:12
# user_id:1259 user_label:32
# user_id:1260 user_label:37
# user_id:1261 user_label:17
# user_id:1262 user_label:14
# user_id:1263 user_label:89
# user_id:1264 user_label:17
# user_id:1265 user_label:55
# user_id:1266 user_label:7
# user_id:1267 user_label:6
# user_id:1268 user_label:32
# user_id:1269 user_label:91
# user_id:1270 user_label:6
# user_id:1271 user_label:77
# user_id:1272 user_label:16
# user_id:1273 user_label:7
# user_id:1274 user_label:1
# user_id:1275 user_label:37
# user_id:1276 user_label:89
# user_id:1277 user_label:54
# user_id:1278 user_label:17
# user_id:1279 user_label:2
# user_id:1280 user_label:2
# user_id:1281 user_label:89
# user_id:1282 user_label:95
# user_id:1283 user_label:2
# user_id:1284 user_label:89
# user_id:1285 user_label:84
# user_id:1286 user_label:17
# user_id:1287 user_label:25
# user_id:1288 user_label:31
# user_id:1289 user_label:91
# user_id:1290 user_label:16
# user_id:1291 user_label:90
# user_id:1292 user_label:1
# user_id:1293 user_label:74
# user_id:1294 user_label:77
# user_id:1295 user_label:31
# user_id:1296 user_label:89
# user_id:1297 user_label:46
# user_id:1298 user_label:31
# user_id:1299 user_label:3
# user_id:1300 user_label:31
# user_id:1301 user_label:90
# user_id:1302 user_label:17
# user_id:1303 user_label:58
# user_id:1304 user_label:89
# user_id:1305 user_label:95
# user_id:1306 user_label:12
# user_id:1307 user_label:57
# user_id:1308 user_label:6
# user_id:1309 user_label:94
# user_id:1310 user_label:90
# user_id:1311 user_label:3
# user_id:1312 user_label:77
# user_id:1313 user_label:91
# user_id:1314 user_label:17
# user_id:1315 user_label:57
# user_id:1316 user_label:74
# user_id:1317 user_label:7
# user_id:1318 user_label:14
# user_id:1319 user_label:3
# user_id:1320 user_label:35
# user_id:1321 user_label:77
# user_id:1322 user_label:28
# user_id:1323 user_label:16
# user_id:1324 user_label:28
# user_id:1325 user_label:1
# user_id:1326 user_label:14
# user_id:1327 user_label:78
# user_id:1328 user_label:2
# user_id:1329 user_label:14
# user_id:1330 user_label:90
# user_id:1331 user_label:78
# user_id:1332 user_label:55
# user_id:1333 user_label:24
# user_id:1334 user_label:17
# user_id:1335 user_label:90
# user_id:1336 user_label:78
# user_id:1337 user_label:91
# user_id:1338 user_label:77
# user_id:1339 user_label:74
# user_id:1340 user_label:94
# user_id:1341 user_label:57
# user_id:1342 user_label:3
# user_id:1343 user_label:77
# user_id:1344 user_label:46
# user_id:1345 user_label:24
# user_id:1346 user_label:81
# user_id:1347 user_label:1
# user_id:1348 user_label:78
# user_id:1349 user_label:95
# user_id:1350 user_label:5
# user_id:1351 user_label:57
# user_id:1352 user_label:87
# user_id:1353 user_label:14
# user_id:1354 user_label:37
# user_id:1355 user_label:32
# user_id:1356 user_label:9
# user_id:1357 user_label:94
# user_id:1358 user_label:6
# user_id:1359 user_label:7
# user_id:1360 user_label:17
# user_id:1361 user_label:14
# user_id:1362 user_label:94
# user_id:1363 user_label:46
# user_id:1364 user_label:3
# user_id:1365 user_label:89
# user_id:1366 user_label:24
# user_id:1367 user_label:3
# user_id:1368 user_label:7
# user_id:1369 user_label:38
# user_id:1370 user_label:94
# user_id:1371 user_label:31
# user_id:1372 user_label:31
# user_id:1373 user_label:9
# user_id:1374 user_label:87
# user_id:1375 user_label:25
# user_id:1376 user_label:14
# user_id:1377 user_label:10
# user_id:1378 user_label:5
# user_id:1379 user_label:7
# user_id:1380 user_label:28
# user_id:1381 user_label:9
# user_id:1382 user_label:9
# user_id:1383 user_label:57
# user_id:1384 user_label:6
# user_id:1385 user_label:97
# user_id:1386 user_label:6
# user_id:1387 user_label:32
# user_id:1388 user_label:1
# user_id:1389 user_label:91
# user_id:1390 user_label:24
# user_id:1391 user_label:91
# user_id:1392 user_label:17
# user_id:1393 user_label:5
# user_id:1394 user_label:24
# user_id:1395 user_label:14
# user_id:1396 user_label:54
# user_id:1397 user_label:32
# user_id:1398 user_label:3
# user_id:1399 user_label:60
# user_id:1400 user_label:31
# user_id:1401 user_label:32
# user_id:1402 user_label:91
# user_id:1403 user_label:7
# user_id:1404 user_label:32
# user_id:1405 user_label:25
# user_id:1406 user_label:6
# user_id:1407 user_label:80
# user_id:1408 user_label:35
# user_id:1409 user_label:32
# user_id:1410 user_label:74
# user_id:1411 user_label:94
# user_id:1412 user_label:91
# user_id:1413 user_label:54
# user_id:1414 user_label:17
# user_id:1415 user_label:78
# user_id:1416 user_label:77
# user_id:1417 user_label:94
# user_id:1418 user_label:57
# user_id:1419 user_label:74
# user_id:1420 user_label:78
# user_id:1421 user_label:77
# user_id:1422 user_label:2
# user_id:1423 user_label:24
# user_id:1424 user_label:17
# user_id:1425 user_label:25
# user_id:1426 user_label:6
# user_id:1427 user_label:3
# user_id:1428 user_label:78
# user_id:1429 user_label:32
# user_id:1430 user_label:4
# user_id:1431 user_label:17
# user_id:1432 user_label:31
# user_id:1433 user_label:31
# user_id:1434 user_label:89
# user_id:1435 user_label:58
# user_id:1436 user_label:6
# user_id:1437 user_label:94
# user_id:1438 user_label:95
# user_id:1439 user_label:12
# user_id:1440 user_label:90
# user_id:1441 user_label:3
# user_id:1442 user_label:1
# user_id:1443 user_label:32
# user_id:1444 user_label:28
# user_id:1445 user_label:17
# user_id:1446 user_label:14
# user_id:1447 user_label:87
# user_id:1448 user_label:77
# user_id:1449 user_label:87
# user_id:1450 user_label:95
# user_id:1451 user_label:57
# user_id:1452 user_label:17
# user_id:1453 user_label:3
# user_id:1454 user_label:3
# user_id:1455 user_label:38
# user_id:1456 user_label:25
# user_id:1457 user_label:77
# user_id:1458 user_label:89
# user_id:1459 user_label:2
# user_id:1460 user_label:4
# user_id:1461 user_label:3
# user_id:1462 user_label:95
# user_id:1463 user_label:32
# user_id:1464 user_label:55
# user_id:1465 user_label:2
# user_id:1466 user_label:58
# user_id:1467 user_label:57
# user_id:1468 user_label:87
# user_id:1469 user_label:31
# user_id:1470 user_label:87
# user_id:1471 user_label:26
# user_id:1472 user_label:80
# user_id:1473 user_label:57
# user_id:1474 user_label:2
# user_id:1475 user_label:89
# user_id:1476 user_label:78
# user_id:1477 user_label:32
# user_id:1478 user_label:95
# user_id:1479 user_label:3
# user_id:1480 user_label:89
# user_id:1481 user_label:7
# user_id:1482 user_label:28
# user_id:1483 user_label:31
# user_id:1484 user_label:35
# user_id:1485 user_label:14
# user_id:1486 user_label:95
# user_id:1487 user_label:31
# user_id:1488 user_label:25
# user_id:1489 user_label:94
# user_id:1490 user_label:94
# user_id:1491 user_label:80
# user_id:1492 user_label:78
# user_id:1493 user_label:25
# user_id:1494 user_label:58
# user_id:1495 user_label:72
# user_id:1496 user_label:32
# user_id:1497 user_label:32
# user_id:1498 user_label:14
# user_id:1499 user_label:46
# user_id:1500 user_label:90
# user_id:1501 user_label:57
# user_id:1502 user_label:32
# user_id:1503 user_label:28
# user_id:1504 user_label:80
# user_id:1505 user_label:95
# user_id:1506 user_label:87
# user_id:1507 user_label:88
# user_id:1508 user_label:24
# user_id:1509 user_label:16
# user_id:1510 user_label:16
# user_id:1511 user_label:7
# user_id:1512 user_label:80
# user_id:1513 user_label:32
# user_id:1514 user_label:46
# user_id:1515 user_label:25
# user_id:1516 user_label:37
# user_id:1517 user_label:5
# user_id:1518 user_label:17
# user_id:1519 user_label:5
# user_id:1520 user_label:72
# user_id:1521 user_label:54
# user_id:1522 user_label:5
# user_id:1523 user_label:87
# user_id:1524 user_label:11
# user_id:1525 user_label:6
# user_id:1526 user_label:14
# user_id:1527 user_label:32
# user_id:1528 user_label:55
# user_id:1529 user_label:90
# user_id:1530 user_label:90
# user_id:1531 user_label:95
# user_id:1532 user_label:17
# user_id:1533 user_label:38
# user_id:1534 user_label:89
# user_id:1535 user_label:31
# user_id:1536 user_label:14
# user_id:1537 user_label:74
# user_id:1538 user_label:89
# user_id:1539 user_label:17
# user_id:1540 user_label:32
# user_id:1541 user_label:2
# user_id:1542 user_label:32
# user_id:1543 user_label:4
# user_id:1544 user_label:89
# user_id:1545 user_label:54
# user_id:1546 user_label:35
# user_id:1547 user_label:23
# user_id:1548 user_label:91
# user_id:1549 user_label:94
# user_id:1550 user_label:74
# user_id:1551 user_label:11
# user_id:1552 user_label:90
# user_id:1553 user_label:1
# user_id:1554 user_label:3
# user_id:1555 user_label:87
# user_id:1556 user_label:58
# user_id:1557 user_label:32
# user_id:1558 user_label:88
# user_id:1559 user_label:74
# user_id:1560 user_label:32
# user_id:1561 user_label:32
# user_id:1562 user_label:57
# user_id:1563 user_label:38
# user_id:1564 user_label:60
# user_id:1565 user_label:90
# user_id:1566 user_label:95
# user_id:1567 user_label:37
# user_id:1568 user_label:24
# user_id:1569 user_label:32
# user_id:1570 user_label:28
# user_id:1571 user_label:5
# user_id:1572 user_label:28
# user_id:1573 user_label:54
# user_id:1574 user_label:37
# user_id:1575 user_label:74
# user_id:1576 user_label:14
# user_id:1577 user_label:94
# user_id:1578 user_label:2
# user_id:1579 user_label:24
# user_id:1580 user_label:77
# user_id:1581 user_label:3
# user_id:1582 user_label:9
# user_id:1583 user_label:95
# user_id:1584 user_label:80
# user_id:1585 user_label:31
# user_id:1586 user_label:17
# user_id:1587 user_label:60
# user_id:1588 user_label:14
# user_id:1589 user_label:14
# user_id:1590 user_label:17
# user_id:1591 user_label:2
# user_id:1592 user_label:35
# user_id:1593 user_label:4
# user_id:1594 user_label:31
# user_id:1595 user_label:2
# user_id:1596 user_label:90
# user_id:1597 user_label:7
# user_id:1598 user_label:74
# user_id:1599 user_label:1
# user_id:1600 user_label:16
# user_id:1601 user_label:6
# user_id:1602 user_label:4
# user_id:1603 user_label:95
# user_id:1604 user_label:78
# user_id:1605 user_label:60
# user_id:1606 user_label:4
# user_id:1607 user_label:37
# user_id:1608 user_label:90
# user_id:1609 user_label:16
# user_id:1610 user_label:7
# user_id:1611 user_label:54
# user_id:1612 user_label:55
# user_id:1613 user_label:78
# user_id:1614 user_label:9
# user_id:1615 user_label:94
# user_id:1616 user_label:3
# user_id:1617 user_label:2
# user_id:1618 user_label:80
# user_id:1619 user_label:31
# user_id:1620 user_label:91
# user_id:1621 user_label:54
# user_id:1622 user_label:97
# user_id:1623 user_label:3
# user_id:1624 user_label:31
# user_id:1625 user_label:97
# user_id:1626 user_label:1
# user_id:1627 user_label:31
# user_id:1628 user_label:12
# user_id:1629 user_label:28
# user_id:1630 user_label:32
# user_id:1631 user_label:91
# user_id:1632 user_label:32
# user_id:1633 user_label:95
# user_id:1634 user_label:17
# user_id:1635 user_label:1
# user_id:1636 user_label:32
# user_id:1637 user_label:2
# user_id:1638 user_label:54
# user_id:1639 user_label:14
# user_id:1640 user_label:1
# user_id:1641 user_label:90
# user_id:1642 user_label:80
# user_id:1643 user_label:95
# user_id:1644 user_label:80
# user_id:1645 user_label:16
# user_id:1646 user_label:95
# user_id:1647 user_label:78
# user_id:1648 user_label:91
# user_id:1649 user_label:74
# user_id:1650 user_label:89
# user_id:1651 user_label:55
# user_id:1652 user_label:12
# user_id:1653 user_label:97
# user_id:1654 user_label:90
# user_id:1655 user_label:32
# user_id:1656 user_label:87
# user_id:1657 user_label:1
# user_id:1658 user_label:77
# user_id:1659 user_label:89
# user_id:1660 user_label:17
# user_id:1661 user_label:31
# user_id:1662 user_label:37
# user_id:1663 user_label:32
# user_id:1664 user_label:57
# user_id:1665 user_label:70
# user_id:1666 user_label:1
# user_id:1667 user_label:95
# user_id:1668 user_label:1
# user_id:1669 user_label:32
# user_id:1670 user_label:90
# user_id:1671 user_label:14
# user_id:1672 user_label:95
# user_id:1673 user_label:57
# user_id:1674 user_label:11
# user_id:1675 user_label:17
# user_id:1676 user_label:28
# user_id:1677 user_label:55
# user_id:1678 user_label:89
# user_id:1679 user_label:95
# user_id:1680 user_label:7
# user_id:1681 user_label:6
# user_id:1682 user_label:2
# user_id:1683 user_label:82
# user_id:1684 user_label:2
# user_id:1685 user_label:55
# user_id:1686 user_label:11
# user_id:1687 user_label:3
# user_id:1688 user_label:91
# user_id:1689 user_label:24
# user_id:1690 user_label:89
# user_id:1691 user_label:97
# user_id:1692 user_label:17
# user_id:1693 user_label:7
# user_id:1694 user_label:14
# user_id:1695 user_label:32
# user_id:1696 user_label:54
# user_id:1697 user_label:28
# user_id:1698 user_label:4
# user_id:1699 user_label:7
# user_id:1700 user_label:24
# user_id:1701 user_label:23
# user_id:1702 user_label:7
# user_id:1703 user_label:15
# user_id:1704 user_label:16
# user_id:1705 user_label:77
# user_id:1706 user_label:80
# user_id:1707 user_label:89
# user_id:1708 user_label:14
# user_id:1709 user_label:5
# user_id:1710 user_label:1
# user_id:1711 user_label:15
# user_id:1712 user_label:31
# user_id:1713 user_label:3
# user_id:1714 user_label:60
# user_id:1715 user_label:14
# user_id:1716 user_label:54
# user_id:1717 user_label:74
# user_id:1718 user_label:87
# user_id:1719 user_label:89
# user_id:1720 user_label:17
# user_id:1721 user_label:24
# user_id:1722 user_label:9
# user_id:1723 user_label:12
# user_id:1724 user_label:14
# user_id:1725 user_label:3
# user_id:1726 user_label:14
# user_id:1727 user_label:32
# user_id:1728 user_label:17
# user_id:1729 user_label:91
# user_id:1730 user_label:2
# user_id:1731 user_label:32
# user_id:1732 user_label:94
# user_id:1733 user_label:3
# user_id:1734 user_label:37
# user_id:1735 user_label:16
# user_id:1736 user_label:78
# user_id:1737 user_label:3
# user_id:1738 user_label:1
# user_id:1739 user_label:24
# user_id:1740 user_label:1
# user_id:1741 user_label:2
# user_id:1742 user_label:74
# user_id:1743 user_label:60
# user_id:1744 user_label:32
# user_id:1745 user_label:7
# user_id:1746 user_label:7
# user_id:1747 user_label:58
# user_id:1748 user_label:17
# user_id:1749 user_label:91
# ...
# user_id:2201 user_label:32
# user_id:2202 user_label:89
# user_id:2203 user_label:37
# user_id:2204 user_label:25
# user_id:2205 user_label:91
# user_id:2206 user_label:89
# user_id:2207 user_label:78
# user_id:2208 user_label:12
# user_id:2209 user_label:88
# user_id:2210 user_label:31
# user_id:2211 user_label:14
# user_id:2212 user_label:5
# user_id:2213 user_label:7
# user_id:2214 user_label:3
# user_id:2215 user_label:43
# user_id:2216 user_label:32
# user_id:2217 user_label:89
# user_id:2218 user_label:7
# user_id:2219 user_label:89
# user_id:2220 user_label:57
# user_id:2221 user_label:2
# user_id:2222 user_label:12
# user_id:2223 user_label:7
# user_id:2224 user_label:78
# user_id:2225 user_label:72
# user_id:2226 user_label:7
# user_id:2227 user_label:17
# user_id:2228 user_label:9
# user_id:2229 user_label:14
# user_id:2230 user_label:14
# user_id:2231 user_label:12
# user_id:2232 user_label:37
# user_id:2233 user_label:9
# user_id:2234 user_label:7
# user_id:2235 user_label:5
# user_id:2236 user_label:31
# user_id:2237 user_label:91
# user_id:2238 user_label:3
# user_id:2239 user_label:74
# user_id:2240 user_label:89
# user_id:2241 user_label:31
# user_id:2242 user_label:23
# user_id:2243 user_label:3
# user_id:2244 user_label:7
# user_id:2245 user_label:4
# user_id:2246 user_label:3
# user_id:2247 user_label:94
# user_id:2248 user_label:74
# user_id:2249 user_label:94
# user_id:2250 user_label:97
# user_id:2251 user_label:67
# user_id:2252 user_label:60
# user_id:2253 user_label:97
# user_id:2254 user_label:31
# user_id:2255 user_label:95
# user_id:2256 user_label:32
# user_id:2257 user_label:24
# user_id:2258 user_label:4
# user_id:2259 user_label:97
# user_id:2260 user_label:46
# user_id:2261 user_label:94
# user_id:2262 user_label:37
# user_id:2263 user_label:4
# user_id:2264 user_label:7
# user_id:2265 user_label:32
# user_id:2266 user_label:91
# user_id:2267 user_label:28
# user_id:2268 user_label:3
# user_id:2269 user_label:31
# user_id:2270 user_label:58
# user_id:2271 user_label:15
# user_id:2272 user_label:14
# user_id:2273 user_label:97
# user_id:2274 user_label:75
# user_id:2275 user_label:74
# user_id:2276 user_label:1
# user_id:2277 user_label:28
# user_id:2278 user_label:14
# user_id:2279 user_label:28
# user_id:2280 user_label:15
# user_id:2281 user_label:57
# user_id:2282 user_label:16
# user_id:2283 user_label:74
# user_id:2284 user_label:80
# user_id:2285 user_label:78
# user_id:2286 user_label:97
# user_id:2287 user_label:90
# user_id:2288 user_label:25
# user_id:2289 user_label:2
# user_id:2290 user_label:55
# user_id:2291 user_label:11
# user_id:2292 user_label:88
# user_id:2293 user_label:87
# user_id:2294 user_label:11
# user_id:2295 user_label:6
# user_id:2296 user_label:38
# user_id:2297 user_label:3
# user_id:2298 user_label:91
# user_id:2299 user_label:90
# user_id:2300 user_label:17
# user_id:2301 user_label:95
# user_id:2302 user_label:7
# user_id:2303 user_label:24
# user_id:2304 user_label:31
# user_id:2305 user_label:95
# user_id:2306 user_label:17
# user_id:2307 user_label:45
# user_id:2308 user_label:28
# user_id:2309 user_label:57
# user_id:2310 user_label:32
# user_id:2311 user_label:2
# user_id:2312 user_label:2
# user_id:2313 user_label:17
# user_id:2314 user_label:6
# user_id:2315 user_label:6
# user_id:2316 user_label:28
# user_id:2317 user_label:4
# user_id:2318 user_label:7
# user_id:2319 user_label:80
# user_id:2320 user_label:80
# user_id:2321 user_label:1
# user_id:2322 user_label:54
# user_id:2323 user_label:6
# user_id:2324 user_label:77
# user_id:2325 user_label:74
# user_id:2326 user_label:78
# user_id:2327 user_label:6
# user_id:2328 user_label:31
# user_id:2329 user_label:2
# user_id:2330 user_label:60
# user_id:2331 user_label:55
# user_id:2332 user_label:94
# user_id:2333 user_label:80
# user_id:2334 user_label:97
# user_id:2335 user_label:7
# user_id:2336 user_label:95
# user_id:2337 user_label:15
# user_id:2338 user_label:90
# user_id:2339 user_label:89
# user_id:2340 user_label:60
# user_id:2341 user_label:90
# user_id:2342 user_label:2
# user_id:2343 user_label:28
# user_id:2344 user_label:77
# user_id:2345 user_label:94
# user_id:2346 user_label:89
# user_id:2347 user_label:7
# user_id:2348 user_label:89
# user_id:2349 user_label:1
# user_id:2350 user_label:94
# user_id:2351 user_label:55
# user_id:2352 user_label:54
# user_id:2353 user_label:91
# user_id:2354 user_label:3
# user_id:2355 user_label:3
# user_id:2356 user_label:87
# user_id:2357 user_label:91
# user_id:2358 user_label:31
# user_id:2359 user_label:28
# user_id:2360 user_label:57
# user_id:2361 user_label:14
# user_id:2362 user_label:74
# user_id:2363 user_label:1
# user_id:2364 user_label:80
# user_id:2365 user_label:68
# user_id:2366 user_label:95
# user_id:2367 user_label:3
# user_id:2368 user_label:7
# user_id:2369 user_label:31
# user_id:2370 user_label:58
# user_id:2371 user_label:88
# user_id:2372 user_label:95
# user_id:2373 user_label:4
# user_id:2374 user_label:7
# user_id:2375 user_label:74
# user_id:2376 user_label:95
# user_id:2377 user_label:10
# user_id:2378 user_label:7
# user_id:2379 user_label:97
# user_id:2380 user_label:3
# user_id:2381 user_label:77
# user_id:2382 user_label:94
# user_id:2383 user_label:54
# user_id:2384 user_label:89
# user_id:2385 user_label:6
# user_id:2386 user_label:4
# user_id:2387 user_label:4
# user_id:2388 user_label:2
# user_id:2389 user_label:54
# user_id:2390 user_label:4
# user_id:2391 user_label:90
# user_id:2392 user_label:14
# user_id:2393 user_label:24
# user_id:2394 user_label:74
# user_id:2395 user_label:1
# user_id:2396 user_label:7
# user_id:2397 user_label:94
# user_id:2398 user_label:4
# user_id:2399 user_label:38
# user_id:2400 user_label:95
# user_id:2401 user_label:38
# user_id:2402 user_label:91
# user_id:2403 user_label:1
# user_id:2404 user_label:16
# user_id:2405 user_label:90
# user_id:2406 user_label:3
# user_id:2407 user_label:3
# user_id:2408 user_label:24
# user_id:2409 user_label:7
# user_id:2410 user_label:95
# user_id:2411 user_label:78
# user_id:2412 user_label:94
# user_id:2413 user_label:77
# user_id:2414 user_label:3
# user_id:2415 user_label:1
# user_id:2416 user_label:91
# user_id:2417 user_label:17
# user_id:2418 user_label:15
# user_id:2419 user_label:14
# user_id:2420 user_label:57
# user_id:2421 user_label:46
# user_id:2422 user_label:89
# user_id:2423 user_label:4
# user_id:2424 user_label:95
# user_id:2425 user_label:4
# user_id:2426 user_label:90
# user_id:2427 user_label:1
# user_id:2428 user_label:90
# user_id:2429 user_label:77
# user_id:2430 user_label:77
# user_id:2431 user_label:68
# user_id:2432 user_label:3
# user_id:2433 user_label:97
# user_id:2434 user_label:89
# user_id:2435 user_label:91
# user_id:2436 user_label:91
# user_id:2437 user_label:1
# user_id:2438 user_label:80
# user_id:2439 user_label:1
# user_id:2440 user_label:9
# user_id:2441 user_label:7
# user_id:2442 user_label:80
# user_id:2443 user_label:31
# user_id:2444 user_label:28
# user_id:2445 user_label:58
# user_id:2446 user_label:77
# user_id:2447 user_label:74
# user_id:2448 user_label:57
# user_id:2449 user_label:15
# user_id:2450 user_label:38
# user_id:2451 user_label:32
# user_id:2452 user_label:94
# user_id:2453 user_label:54
# user_id:2454 user_label:54
# user_id:2455 user_label:12
# user_id:2456 user_label:4
# user_id:2457 user_label:90
# user_id:2458 user_label:4
# user_id:2459 user_label:7
# user_id:2460 user_label:3
# user_id:2461 user_label:97
# user_id:2462 user_label:3
# user_id:2463 user_label:31
# user_id:2464 user_label:1
# user_id:2465 user_label:89
# user_id:2466 user_label:58
# user_id:2467 user_label:94
# user_id:2468 user_label:74
# user_id:2469 user_label:58
# user_id:2470 user_label:4
# user_id:2471 user_label:4
# user_id:2472 user_label:7
# user_id:2473 user_label:87
# user_id:2474 user_label:91
# user_id:2475 user_label:31
# user_id:2476 user_label:4
# user_id:2477 user_label:74
# user_id:2478 user_label:95
# user_id:2479 user_label:91
# user_id:2480 user_label:94
# user_id:2481 user_label:14
# user_id:2482 user_label:55
# user_id:2483 user_label:54
# user_id:2484 user_label:15
# user_id:2485 user_label:95
# user_id:2486 user_label:3
# user_id:2487 user_label:84
# user_id:2488 user_label:90
# user_id:2489 user_label:17
# user_id:2490 user_label:25
# user_id:2491 user_label:95
# user_id:2492 user_label:14
# user_id:2493 user_label:3
# user_id:2494 user_label:37
# user_id:2495 user_label:37
# user_id:2496 user_label:95
# user_id:2497 user_label:89
# user_id:2498 user_label:58
# user_id:2499 user_label:90
# user_id:2500 user_label:89
# user_id:2501 user_label:91
# user_id:2502 user_label:55
# user_id:2503 user_label:15
# user_id:2504 user_label:28
# user_id:2505 user_label:80
# user_id:2506 user_label:31
# user_id:2507 user_label:17
# user_id:2508 user_label:55
# user_id:2509 user_label:74
# user_id:2510 user_label:97
# user_id:2511 user_label:31
# user_id:2512 user_label:57
# user_id:2513 user_label:17
# user_id:2514 user_label:89
# user_id:2515 user_label:24
# user_id:2516 user_label:89
# user_id:2517 user_label:4
# user_id:2518 user_label:91
# user_id:2519 user_label:74
# user_id:2520 user_label:90
# user_id:2521 user_label:16
# user_id:2522 user_label:74
# user_id:2523 user_label:17
# user_id:2524 user_label:57
# user_id:2525 user_label:26
# user_id:2526 user_label:91
# user_id:2527 user_label:7
# user_id:2528 user_label:55
# user_id:2529 user_label:14
# user_id:2530 user_label:97
# user_id:2531 user_label:2
# user_id:2532 user_label:14
# user_id:2533 user_label:3
# user_id:2534 user_label:24
# user_id:2535 user_label:90
# user_id:2536 user_label:32
# user_id:2537 user_label:74
# user_id:2538 user_label:87
# user_id:2539 user_label:91
# user_id:2540 user_label:16
# user_id:2541 user_label:1
# user_id:2542 user_label:54
# user_id:2543 user_label:89
# user_id:2544 user_label:74
# user_id:2545 user_label:1
# user_id:2546 user_label:2
# user_id:2547 user_label:91
# user_id:2548 user_label:17
# user_id:2549 user_label:2
# user_id:2550 user_label:72
# user_id:2551 user_label:89
# user_id:2552 user_label:28
# user_id:2553 user_label:2
# user_id:2554 user_label:2
# user_id:2555 user_label:32
# user_id:2556 user_label:94
# user_id:2557 user_label:2
# user_id:2558 user_label:77
# user_id:2559 user_label:55
# user_id:2560 user_label:77
# user_id:2561 user_label:1
# user_id:2562 user_label:16
# user_id:2563 user_label:25
# user_id:2564 user_label:54
# user_id:2565 user_label:77
# user_id:2566 user_label:88
# user_id:2567 user_label:14
# user_id:2568 user_label:55
# user_id:2569 user_label:5
# user_id:2570 user_label:58
# user_id:2571 user_label:4
# user_id:2572 user_label:58
# user_id:2573 user_label:89
# user_id:2574 user_label:28
# user_id:2575 user_label:57
# user_id:2576 user_label:2
# user_id:2577 user_label:97
# user_id:2578 user_label:90
# user_id:2579 user_label:87
# user_id:2580 user_label:95
# user_id:2581 user_label:31
# user_id:2582 user_label:37
# user_id:2583 user_label:24
# user_id:2584 user_label:32
# user_id:2585 user_label:95
# user_id:2586 user_label:5
# user_id:2587 user_label:6
# user_id:2588 user_label:2
# user_id:2589 user_label:9
# user_id:2590 user_label:94
# user_id:2591 user_label:87
# user_id:2592 user_label:37
# user_id:2593 user_label:32
# user_id:2594 user_label:78
# user_id:2595 user_label:1
# user_id:2596 user_label:90
# user_id:2597 user_label:77
# user_id:2598 user_label:14
# user_id:2599 user_label:17
# user_id:2600 user_label:95
# user_id:2601 user_label:31
# user_id:2602 user_label:95
# user_id:2603 user_label:11
# user_id:2604 user_label:74
# user_id:2605 user_label:4
# user_id:2606 user_label:3
# user_id:2607 user_label:90
# user_id:2608 user_label:17
# user_id:2609 user_label:17
# user_id:2610 user_label:54
# user_id:2611 user_label:90
# user_id:2612 user_label:78
# user_id:2613 user_label:3
# user_id:2614 user_label:77
# user_id:2615 user_label:55
# user_id:2616 user_label:37
# user_id:2617 user_label:89
# user_id:2618 user_label:23
# user_id:2619 user_label:25
# user_id:2620 user_label:74
# user_id:2621 user_label:17
# user_id:2622 user_label:95
# user_id:2623 user_label:5
# user_id:2624 user_label:3
# user_id:2625 user_label:1
# user_id:2626 user_label:95
# user_id:2627 user_label:95
# user_id:2628 user_label:90
# user_id:2629 user_label:14
# user_id:2630 user_label:5
# user_id:2631 user_label:58
# user_id:2632 user_label:3
# user_id:2633 user_label:97
# user_id:2634 user_label:4
# user_id:2635 user_label:72
# user_id:2636 user_label:74
# user_id:2637 user_label:32
# user_id:2638 user_label:28
# user_id:2639 user_label:5
# user_id:2640 user_label:7
# user_id:2641 user_label:78
# user_id:2642 user_label:6
# user_id:2643 user_label:32
# user_id:2644 user_label:95
# user_id:2645 user_label:14
# user_id:2646 user_label:58
# user_id:2647 user_label:1
# user_id:2648 user_label:16
# user_id:2649 user_label:94
# user_id:2650 user_label:60
# user_id:2651 user_label:5
# user_id:2652 user_label:25
# user_id:2653 user_label:32
# user_id:2654 user_label:3
# user_id:2655 user_label:1
# user_id:2656 user_label:90
# user_id:2657 user_label:54
# user_id:2658 user_label:90
# user_id:2659 user_label:90
# user_id:2660 user_label:17
# user_id:2661 user_label:24
# user_id:2662 user_label:1
# user_id:2663 user_label:74
# user_id:2664 user_label:97
# user_id:2665 user_label:32
# user_id:2666 user_label:77
# user_id:2667 user_label:89
# user_id:2668 user_label:14
# user_id:2669 user_label:78
# user_id:2670 user_label:77
# user_id:2671 user_label:14
# user_id:2672 user_label:24
# user_id:2673 user_label:74
# user_id:2674 user_label:32
# user_id:2675 user_label:46
# user_id:2676 user_label:97
# user_id:2677 user_label:95
# user_id:2678 user_label:16
# user_id:2679 user_label:7
# user_id:2680 user_label:90
# user_id:2681 user_label:90
# user_id:2682 user_label:9
# user_id:2683 user_label:54
# user_id:2684 user_label:89
# user_id:2685 user_label:14
# user_id:2686 user_label:7
# user_id:2687 user_label:2
# user_id:2688 user_label:17
# user_id:2689 user_label:95
# user_id:2690 user_label:4
# user_id:2691 user_label:1
# user_id:2692 user_label:2
# user_id:2693 user_label:5
# user_id:2694 user_label:96
# user_id:2695 user_label:74
# user_id:2696 user_label:3
# user_id:2697 user_label:54
# user_id:2698 user_label:6
# user_id:2699 user_label:24
# user_id:2700 user_label:38
# user_id:2701 user_label:4
# user_id:2702 user_label:25
# user_id:2703 user_label:77
# user_id:2704 user_label:89
# user_id:2705 user_label:23
# user_id:2706 user_label:90
# user_id:2707 user_label:6
# user_id:2708 user_label:60
# user_id:2709 user_label:1
# user_id:2710 user_label:14
# user_id:2711 user_label:89
# user_id:2712 user_label:91
# user_id:2713 user_label:3
# user_id:2714 user_label:31
# user_id:2715 user_label:57
# user_id:2716 user_label:14
# user_id:2717 user_label:1
# user_id:2718 user_label:17
# user_id:2719 user_label:80
# user_id:2720 user_label:74
# user_id:2721 user_label:24
# user_id:2722 user_label:14
# user_id:2723 user_label:6
# user_id:2724 user_label:4
# user_id:2725 user_label:37
# user_id:2726 user_label:91
# user_id:2727 user_label:90
# user_id:2728 user_label:37
# user_id:2729 user_label:24
# user_id:2730 user_label:6
# user_id:2731 user_label:31
# user_id:2732 user_label:28
# user_id:2733 user_label:89
# user_id:2734 user_label:16
# user_id:2735 user_label:57
# user_id:2736 user_label:96
# user_id:2737 user_label:3
# user_id:2738 user_label:31
# user_id:2739 user_label:16
# user_id:2740 user_label:97
# user_id:2741 user_label:95
# user_id:2742 user_label:88
# user_id:2743 user_label:97
# user_id:2744 user_label:37
# user_id:2745 user_label:80
# user_id:2746 user_label:57
# user_id:2747 user_label:78
# user_id:2748 user_label:17
# user_id:2749 user_label:58
# user_id:2750 user_label:17
# user_id:2751 user_label:28
# user_id:2752 user_label:1
# user_id:2753 user_label:55
# user_id:2754 user_label:31
# user_id:2755 user_label:57
# user_id:2756 user_label:54
# user_id:2757 user_label:57
# user_id:2758 user_label:41
# user_id:2759 user_label:16
# user_id:2760 user_label:16
# user_id:2761 user_label:16
# user_id:2762 user_label:89
# user_id:2763 user_label:1
# user_id:2764 user_label:28
# user_id:2765 user_label:14
# user_id:2766 user_label:1
# user_id:2767 user_label:15
# user_id:2768 user_label:6
# user_id:2769 user_label:11
# user_id:2770 user_label:3
# user_id:2771 user_label:37
# user_id:2772 user_label:37
# user_id:2773 user_label:97
# user_id:2774 user_label:74
# user_id:2775 user_label:31
# user_id:2776 user_label:74
# user_id:2777 user_label:91
# user_id:2778 user_label:57
# user_id:2779 user_label:2
# user_id:2780 user_label:89
# user_id:2781 user_label:32
# user_id:2782 user_label:94
# user_id:2783 user_label:77
# user_id:2784 user_label:14
# user_id:2785 user_label:7
# user_id:2786 user_label:77
# user_id:2787 user_label:16
# user_id:2788 user_label:28
# user_id:2789 user_label:5
# user_id:2790 user_label:80
# user_id:2791 user_label:57
# user_id:2792 user_label:97
# user_id:2793 user_label:14
# user_id:2794 user_label:94
# Found 22 neighbor users/playlists.
# CPU times: user 719 ms, sys: 387 ms, total: 1.11 s
# Wall time: 684 ms

# %%
# get the tracks in similar users' playlists
games = []
for user_id in neighbors:
    games += list(df[df['bundleId'] == int(user_id)]['itemId'])
print('Found {0} neighbor items from these games.'.format(len(games))) 

users = np.full(len(games), desired_user_id, dtype='int32')
bundles = np.array(games, dtype='int32')

print('\nRanking most likely games using the NeuMF model...')
# and predict tracks for my user
results = model.predict([users,bundles],batch_size=100, verbose=0) 
results = results.tolist()
print('Ranked the games!')
# Out:
# Found 138 neighbor items from these games.
#
# Ranking most likely games using the NeuMF model...
# Ranked the games!

# %%
results_df = pd.DataFrame(np.nan, index=range(len(results)), columns=['probability','item_name', 'genre'])
print(results_df.shape)

# loop through and get the probability (of being in the bundle according to my model), the game, and the genre  
for i, prob in enumerate(results):
    print('i: {0} prob: {1}'.format(i,prob))
    results_df.loc[i] = [prob[0], df[df['itemId'] == i].iloc[0]['item_name'], df[df['itemId'] == i].iloc[0]['genre']]
results_df = results_df.sort_values(by=['probability'], ascending=False)

results_df.head(20)
# Out:
# (138, 3)
# i: 0 prob: [0.15298321843147278]
# i: 1 prob: [0.9998869299888611]
# i: 2 prob: [0.04202428460121155]
# i: 3 prob: [2.4170958567992784e-07]
# i: 4 prob: [1.8240148974557613e-11]
# i: 5 prob: [0.7810355424880981]
# i: 6 prob: [0.9919615387916565]
# i: 7 prob: [0.9998305439949036]
# i: 8 prob: [0.21919488906860352]
# i: 9 prob: [0.9997233748435974]
# i: 10 prob: [3.584334265754451e-16]
# i: 11 prob: [0.9911948442459106]
# i: 12 prob: [0.15384966135025024]
# i: 13 prob: [1.2712458407827712e-16]
# i: 14 prob: [0.38211238384246826]
# i: 15 prob: [1.9510556739987805e-05]
# i: 16 prob: [1.9190532839274965e-05]
# i: 17 prob: [0.0011650323867797852]
# i: 18 prob: [0.38211238384246826]
# i: 19 prob: [1.9510556739987805e-05]
# i: 20 prob: [1.9190532839274965e-05]
# i: 21 prob: [0.009297490119934082]
# i: 22 prob: [0.9900289177894592]
# i: 23 prob: [0.9999203681945801]
# i: 24 prob: [0.9993526935577393]
# i: 25 prob: [0.0002168416976928711]
# i: 26 prob: [9.693976608105004e-07]
# i: 27 prob: [1.012312168313656e-05]
# i: 28 prob: [0.9998983144760132]
# i: 29 prob: [0.999594509601593]
# i: 30 prob: [0.9843690395355225]
# i: 31 prob: [0.9998828768730164]
# i: 32 prob: [0.9992971420288086]
# i: 33 prob: [0.9590386748313904]
# i: 34 prob: [0.9993666410446167]
# i: 35 prob: [0.15010109543800354]
# i: 36 prob: [0.9771350622177124]
# i: 37 prob: [0.00046133995056152344]
# i: 38 prob: [0.01267269253730774]
# i: 39 prob: [0.9994258880615234]
# i: 40 prob: [0.9843690395355225]
# i: 41 prob: [0.9847056865692139]
# i: 42 prob: [1.3236382696417979e-15]
# i: 43 prob: [0.9998828768730164]
# i: 44 prob: [0.15010109543800354]
# i: 45 prob: [0.9771350622177124]
# i: 46 prob: [0.9998555183410645]
# i: 47 prob: [0.9992971420288086]
# i: 48 prob: [0.988696813583374]
# i: 49 prob: [0.9590386748313904]
# i: 50 prob: [0.39268195629119873]
# i: 51 prob: [0.10178524255752563]
# i: 52 prob: [0.9998078346252441]
# i: 53 prob: [0.9671486616134644]
# i: 54 prob: [4.4173247302322553e-16]
# i: 55 prob: [0.9769628047943115]
# i: 56 prob: [9.515423075062593e-16]
# i: 57 prob: [0.0001418590545654297]
# i: 58 prob: [0.9999529123306274]
# i: 59 prob: [0.8301298022270203]
# i: 60 prob: [2.3518118596443905e-16]
# i: 61 prob: [0.9966503381729126]
# i: 62 prob: [0.00046133995056152344]
# i: 63 prob: [0.01267269253730774]
# i: 64 prob: [0.9994258880615234]
# i: 65 prob: [0.0009645521640777588]
# i: 66 prob: [0.9988677501678467]
# i: 67 prob: [0.9993666410446167]
# i: 68 prob: [1.3486988791555632e-05]
# i: 69 prob: [0.0031329989433288574]
# i: 70 prob: [0.5014086961746216]
# i: 71 prob: [0.9964249134063721]
# i: 72 prob: [0.9282811284065247]
# i: 73 prob: [0.6558576226234436]
# i: 74 prob: [0.9999253749847412]
# i: 75 prob: [0.06334006786346436]
# i: 76 prob: [4.2678195200096525e-08]
# i: 77 prob: [0.9990394115447998]
# i: 78 prob: [0.9841080904006958]
# i: 79 prob: [0.004448592662811279]
# i: 80 prob: [1.4418869744015073e-13]
# i: 81 prob: [0.999931812286377]
# i: 82 prob: [0.9998570680618286]
# i: 83 prob: [0.9488276839256287]
# i: 84 prob: [0.9240731000900269]
# i: 85 prob: [1.4450190064962953e-05]
# i: 86 prob: [0.9999712705612183]
# i: 87 prob: [0.999675452709198]
# i: 88 prob: [0.9868643283843994]
# i: 89 prob: [0.9995431900024414]
# i: 90 prob: [0.3590853810310364]
# i: 91 prob: [0.9982434511184692]
# i: 92 prob: [0.9989045262336731]
# i: 93 prob: [0.8892162442207336]
# i: 94 prob: [0.9737401008605957]
# i: 95 prob: [2.321841918728751e-07]
# i: 96 prob: [0.9998196363449097]
# i: 97 prob: [2.397975295890454e-18]
# i: 98 prob: [0.996742308139801]
# i: 99 prob: [0.007984250783920288]
# i: 100 prob: [0.9968062043190002]
# i: 101 prob: [0.9996201992034912]
# i: 102 prob: [0.9954716563224792]
# i: 103 prob: [0.9998393058776855]
# i: 104 prob: [0.9999479651451111]
# i: 105 prob: [1.0039790467763392e-15]
# i: 106 prob: [0.04243248701095581]
# i: 107 prob: [0.005949586629867554]
# i: 108 prob: [0.9990741014480591]
# i: 109 prob: [0.7563716769218445]
# i: 110 prob: [0.0771327018737793]
# i: 111 prob: [0.016577064990997314]
# i: 112 prob: [0.9447816014289856]
# i: 113 prob: [0.9987587332725525]
# i: 114 prob: [7.55820561693099e-09]
# i: 115 prob: [0.9758286476135254]
# i: 116 prob: [0.9937596321105957]
# i: 117 prob: [0.9994710683822632]
# i: 118 prob: [0.9999076128005981]
# i: 119 prob: [0.9998029470443726]
# i: 120 prob: [0.5014748573303223]
# i: 121 prob: [1.066657179249475e-11]
# i: 122 prob: [0.7563716769218445]
# i: 123 prob: [0.0771327018737793]
# i: 124 prob: [0.9447816014289856]
# i: 125 prob: [0.9987587332725525]
# i: 126 prob: [0.9758286476135254]
# i: 127 prob: [0.9937596321105957]
# i: 128 prob: [0.9994710683822632]
# i: 129 prob: [0.9447816014289856]
# i: 130 prob: [0.9987587332725525]
# i: 131 prob: [0.9758286476135254]
# i: 132 prob: [0.9937596321105957]
# i: 133 prob: [0.9994710683822632]
# i: 134 prob: [0.9999076724052429]
# i: 135 prob: [0.009056031703948975]
# i: 136 prob: [0.7886521816253662]
# i: 137 prob: [1.4199809811543673e-05]
#      probability  ...                                                      genre
# 86   0.999971     ...
# 58   0.999953     ...
# 104  0.999948     ...  Simulation
# 81   0.999932     ...  Simulation
# 74   0.999925     ...  Strategy, Indie, Casual
# 23   0.999920     ...
# 134  0.999908     ...  Racing, Sports
# 118  0.999908     ...  Racing
# 28   0.999898     ...
# 1    0.999887     ...  Adventure, Indie, RPG
# 43   0.999883     ...  Casual, Free to Play, Indie, Simulation, Sports, Strategy
# 31   0.999883     ...
# 82   0.999857     ...  Simulation
# 46   0.999856     ...  Casual, Free to Play, Indie, Simulation, Sports, Strategy
# 103  0.999839     ...  RPG
# 7    0.999831     ...  Adventure, Casual, Indie
# 96   0.999820     ...
# 52   0.999808     ...
# 119  0.999803     ...  Racing
# 9    0.999723     ...  Adventure, Indie
#
# [20 rows x 3 columns]

# %%
df[df['bundleId'] == 500].head(20)
# Out:
#      item_id                item_name  ... itemId  bundleId
# 2860  298520  Orbital Gear             ...  2289   500
# 2861  358880  Orbital Gear Soundtrack  ...  2290   500
# 2862  424830  Bell Ringer              ...  2291   500
#
# [3 rows x 6 columns]

# %%
#save df to json for inference
df.to_json(r'/content/origin_steam_video_df.json')

# %%
# df.to_json(r'/content/origin_steam_video_df.json')
load_df = pd.read_json('/content/origin_steam_video_df.json')
load_df.head()
# Out:
#   item_id                           item_name  ... itemId  bundleId
# 0  326950  Sword of Asumi                      ...  0      0
# 1  331490  Sword of Asumi - Soundtrack         ...  1      0
# 2  331491  Sword of Asumi - Graphic Novel      ...  2      0
# 3  331492  Sword of Asumi - Character Creator  ...  3      0
# 4  348540  Divine Slice of Life                ...  4      0
#
# [5 rows x 6 columns]

# %%
print(keras.__version__)
# Out:
# 2.4.0
